# %% [markdown]
# A language model predicts the next word in a sequence based off the words that have come before it in the sequence. It's possible to develop language models at the character level using neural networks.
#
#
# The benefit of character-based language models is their small vocabulary and adaptability with words, punctuation, and other documents. The trade off is that, larger models are slower to train.​
#
# However, with neural language models, character-based models offer promise for a general, flexible and powerful approach to language modeling.
#
# Here, this project is meant to be an excerise in implementing a Neural Language Models with a simple nusery rhyme and song lyrics.
#
# What resulted were two models that could predict, with a given input of strings, predict the next sequence of strings thereafter associated with the input.

# %%
from numpy import array
from pickle import dump
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Activation, Dense
from pickle import load
from keras.models import load_model
from keras.utils import to_categorical
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from keras.layers import Embedding

# %%
# generate a sequence of characters with a language model
def generate_seq(model, tokenizer, max_length, seed_text, n_words):
	in_text = seed_text
	# generate a fixed number of words
	for _ in range(n_words):
		 # encode the characters as integers
		encoded = tokenizer.texts_to_sequences([in_text])[0]
		# truncate sequences to a fixed length
		encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')
		# predict character
		yhat = model.predict_classes(encoded, verbose=0)
		# reverse map integer to character
		out_word = ''
		for word, index in tokenizer.word_index.items():
			if index == yhat:
				out_word = word
				break
		# append to input
		in_text += ' ' + out_word
	return in_text

# %% [markdown]
# # Source Text Creation

# %%
# !pip install tensorflow
# !pip install keras
# !pip install h5py
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.6/dist-packages (2.3.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.34.2)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.30.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.9.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.4.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.18.5)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.12.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.17.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (0.4.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (3.2.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.7.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (2.23.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (49.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (1.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (1.24.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (3.1.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (2.4.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.18.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras) (1.15.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)

# %%
s='Sing a song of sixpence,\
A pocket full of rye.\
Four and twenty blackbirds,\
Baked in a pie.\
When the pie was opened\
The birds began to sing;\
Wasn’t that a dainty dish,\
To set before the king.\
The king was in his counting house,\
Counting out his money;\
The queen was in the parlour,\
Eating bread and honey.\
The maid was in the garden,\
Hanging out the clothes,\
When down came a blackbird\
And pecked off her nose.'

with open('rhymes.txt','w') as f:
  f.write(s)

# %% [markdown]
# # Sequence Generation

# %% [markdown]
# Instead of taking the corpus and splitting into individual words then feeding into a model with file imports and whatnot. I instead, used the tokenizer function introduced in the previous labs and tokenized the text to numerical values.
#
# This reduced processing time as the model was not fitting to strings but numerical designations.
#
# I also used kera's prepossing text_to_sequencies which with toeknizer, represents the document as a sequence of interger values, where each word in the document is represented as a unique intiger.
#
# In other words, the function
#
# Splits words by space (split=” “).
# Filters out punctuation.
# Converts text to lowercase.
# I then converted to sequences of integers with the texts_to_sequences() function.
#
# I tried to understand the file outputs originally and the tokenization process that was in the orignal lab outline. However, I saw that the tokenizer funciton from last lab would work on this instead of file inputs and outputs when not necessary.

# %%
#using tokenizer then assigning text to numerical values instead of raw words
tokenizer = Tokenizer()
tokenizer.fit_on_texts([s])
encoded = tokenizer.texts_to_sequences([s])[0]

# %% [markdown]
# The size of the vocabulary function is modified to retrieve the vocab sie from the trained Tokenizer by accessing the word_index attribute.
#
# +1 is added because the integer for the largest encoded word needs to be specified as an array index.
#
# Ex: 1 to 10 with array indcies 0 to 11 or 12 positions.
#
# I orignally tried to vary the size of the sequences manually, but I realized that this was inefficient. Differnt lines had different lengths, such that the sequence size had to be adjusted appropriately for each line individually.

# %%
# vocabulary size
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# Out:
# Vocabulary Size: 51

# %%
# encode n words -> 1 words
sequences = list()
for i in range(2, len(encoded)):
	sequence = encoded[i-2:i+1]
	sequences.append(sequence)

# %%
sequences
# Out:
# [[5, 2, 15],
#  [2, 15, 6],
#  [15, 6, 16],
#  [6, 16, 2],
#  [16, 2, 17],
#  [2, 17, 18],
#  [17, 18, 6],
#  [18, 6, 19],
#  [6, 19, 20],
#  [19, 20, 7],
#  [20, 7, 21],
#  [7, 21, 22],
#  [21, 22, 23],
#  [22, 23, 3],
#  [23, 3, 2],
#  [3, 2, 8],
#  [2, 8, 9],
#  [8, 9, 1],
#  [9, 1, 8],
#  [1, 8, 4],
#  [8, 4, 24],
#  [4, 24, 25],
#  [24, 25, 26],
#  [25, 26, 10],
#  [26, 10, 5],
#  [10, 5, 27],
#  [5, 27, 28],
#  [27, 28, 2],
#  [28, 2, 29],
#  [2, 29, 30],
#  [29, 30, 10],
#  [30, 10, 31],
#  [10, 31, 32],
#  [31, 32, 1],
#  [32, 1, 11],
#  [1, 11, 1],
#  [11, 1, 11],
#  [1, 11, 4],
#  [11, 4, 3],
#  [4, 3, 12],
#  [3, 12, 13],
#  [12, 13, 33],
#  [13, 33, 13],
#  [33, 13, 14],
#  [13, 14, 12],
#  [14, 12, 34],
#  [12, 34, 1],
#  [34, 1, 35],
#  [1, 35, 4],
#  [35, 4, 3],
#  [4, 3, 1],
#  [3, 1, 36],
#  [1, 36, 37],
#  [36, 37, 38],
#  [37, 38, 7],
#  [38, 7, 39],
#  [7, 39, 1],
#  [39, 1, 40],
#  [1, 40, 4],
#  [40, 4, 3],
#  [4, 3, 1],
#  [3, 1, 41],
#  [1, 41, 42],
#  [41, 42, 14],
#  [42, 14, 1],
#  [14, 1, 43],
#  [1, 43, 9],
#  [43, 9, 44],
#  [9, 44, 45],
#  [44, 45, 2],
#  [45, 2, 46],
#  [2, 46, 47],
#  [46, 47, 48],
#  [47, 48, 49],
#  [48, 49, 50]]

# %%
print('Total Sequences: %d' % len(sequences))
# pad sequences
max_length = max([len(seq) for seq in sequences])
sequences = pad_sequences(sequences, maxlen=max_length, padding='pre')
print('Max Sequence Length: %d' % max_length)
# Out:
# Total Sequences: 75
# Max Sequence Length: 3

# %% [markdown]
# # Model Training
#
# Here the text corpus file was split into training and validation sets. The validation data was piped into the model.fit() function in order to track validation error per epoch.

# %% [markdown]
# Below, I wrote a function that split the text corpus file into training and validation and piped the validation data into the model.fit() function.
#
# I tried first to use test train split from scikit, but found I could do this more easily with the documentation of the model.fit() function.

# %%
# separate into input and output
sequences = array(sequences)
X, y = sequences[:,:-1],sequences[:,-1]
y = to_categorical(y, num_classes=vocab_size)

# %% [markdown]
# The model has a single hidden LSTM layer with 42 units. Uses a softmax function to make sure the probability is normalized between 0 and 1.
#
# The model uses a learned word embedding in the input layer. Where each word vector has specified length - a 10-dim specification here - and has one real valued vector for each word in the vocab.

# %%
# define model
model = Sequential()
model.add(Embedding(vocab_size, 10, input_length=max_length-1))
model.add(LSTM(42))
model.add(Dense(vocab_size, activation='softmax'))
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 2, 10)             510
# _________________________________________________________________
# lstm (LSTM)                  (None, 42)                8904
# _________________________________________________________________
# dense (Dense)                (None, 51)                2193
# =================================================================
# Total params: 11,607
# Trainable params: 11,607
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Complied and fit the network on the encoded text data. I used the Adam implementation of gradient descent and tracked accuracy at each epoch ending. About 500 epochs in total.
#
# I then fed the vocab mappings into the sequence generation function defined at the top. This function takes a word then generate an associated sequence.
#
# From the accuracy scores, the model does not perfectly output the associated words tied to singular words all the time.
#
# This is because some words have ambiguity associated them.
#
# Ex: the => pie the => king
#
# When the pie was opened
# The birds began to sing;
# Wasn’t that a dainty dish,
# To set before the king.
#
# The king was in his counting house,
# Counting out his money;
# The queen was in the parlour,
# Eating bread and honey.
#
# The maid was in the garden,
# Hanging out the clothes,
# When down came a blackbird
# And pecked off her nose.
# As shown from the outputs. The model reasonably, with some error, reproduces the associated lines with recognizability.
#
# But it cannot reproduce "hello world" as these words/phrase does not exist within the original word corpus.

# %%
# compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit network
model.fit(X, y, epochs=442, verbose=2)
# Out:
# Epoch 1/442
# 3/3 - 0s - loss: 3.9321 - accuracy: 0.0400
# Epoch 2/442
# 3/3 - 0s - loss: 3.9296 - accuracy: 0.0800
# Epoch 3/442
# 3/3 - 0s - loss: 3.9278 - accuracy: 0.0933
# Epoch 4/442
# 3/3 - 0s - loss: 3.9258 - accuracy: 0.1067
# Epoch 5/442
# 3/3 - 0s - loss: 3.9241 - accuracy: 0.1067
# Epoch 6/442
# 3/3 - 0s - loss: 3.9221 - accuracy: 0.1067
# Epoch 7/442
# 3/3 - 0s - loss: 3.9200 - accuracy: 0.1067
# Epoch 8/442
# 3/3 - 0s - loss: 3.9179 - accuracy: 0.1067
# Epoch 9/442
# 3/3 - 0s - loss: 3.9157 - accuracy: 0.1067
# Epoch 10/442
# 3/3 - 0s - loss: 3.9132 - accuracy: 0.1067
# Epoch 11/442
# 3/3 - 0s - loss: 3.9102 - accuracy: 0.1067
# Epoch 12/442
# 3/3 - 0s - loss: 3.9075 - accuracy: 0.1067
# Epoch 13/442
# 3/3 - 0s - loss: 3.9044 - accuracy: 0.1067
# Epoch 14/442
# 3/3 - 0s - loss: 3.9009 - accuracy: 0.1067
# Epoch 15/442
# 3/3 - 0s - loss: 3.8973 - accuracy: 0.1067
# Epoch 16/442
# 3/3 - 0s - loss: 3.8932 - accuracy: 0.1067
# Epoch 17/442
# 3/3 - 0s - loss: 3.8890 - accuracy: 0.1067
# Epoch 18/442
# 3/3 - 0s - loss: 3.8838 - accuracy: 0.1067
# Epoch 19/442
# 3/3 - 0s - loss: 3.8784 - accuracy: 0.1067
# Epoch 20/442
# 3/3 - 0s - loss: 3.8728 - accuracy: 0.1067
# Epoch 21/442
# 3/3 - 0s - loss: 3.8664 - accuracy: 0.1067
# Epoch 22/442
# 3/3 - 0s - loss: 3.8586 - accuracy: 0.1067
# Epoch 23/442
# 3/3 - 0s - loss: 3.8508 - accuracy: 0.1067
# Epoch 24/442
# 3/3 - 0s - loss: 3.8414 - accuracy: 0.1067
# Epoch 25/442
# 3/3 - 0s - loss: 3.8310 - accuracy: 0.1067
# Epoch 26/442
# 3/3 - 0s - loss: 3.8201 - accuracy: 0.1067
# Epoch 27/442
# 3/3 - 0s - loss: 3.8063 - accuracy: 0.1067
# Epoch 28/442
# 3/3 - 0s - loss: 3.7934 - accuracy: 0.1067
# Epoch 29/442
# 3/3 - 0s - loss: 3.7769 - accuracy: 0.1067
# Epoch 30/442
# 3/3 - 0s - loss: 3.7597 - accuracy: 0.1067
# Epoch 31/442
# 3/3 - 0s - loss: 3.7391 - accuracy: 0.1067
# Epoch 32/442
# 3/3 - 0s - loss: 3.7195 - accuracy: 0.1067
# Epoch 33/442
# 3/3 - 0s - loss: 3.6961 - accuracy: 0.1067
# Epoch 34/442
# 3/3 - 0s - loss: 3.6717 - accuracy: 0.1067
# Epoch 35/442
# 3/3 - 0s - loss: 3.6439 - accuracy: 0.1067
# Epoch 36/442
# 3/3 - 0s - loss: 3.6157 - accuracy: 0.1067
# Epoch 37/442
# 3/3 - 0s - loss: 3.5849 - accuracy: 0.1067
# Epoch 38/442
# 3/3 - 0s - loss: 3.5556 - accuracy: 0.1067
# Epoch 39/442
# 3/3 - 0s - loss: 3.5266 - accuracy: 0.1067
# Epoch 40/442
# 3/3 - 0s - loss: 3.4986 - accuracy: 0.1067
# Epoch 41/442
# 3/3 - 0s - loss: 3.4717 - accuracy: 0.1067
# Epoch 42/442
# 3/3 - 0s - loss: 3.4521 - accuracy: 0.1067
# Epoch 43/442
# 3/3 - 0s - loss: 3.4362 - accuracy: 0.1067
# Epoch 44/442
# 3/3 - 0s - loss: 3.4211 - accuracy: 0.1067
# Epoch 45/442
# 3/3 - 0s - loss: 3.4054 - accuracy: 0.1067
# Epoch 46/442
# 3/3 - 0s - loss: 3.3887 - accuracy: 0.1333
# Epoch 47/442
# 3/3 - 0s - loss: 3.3724 - accuracy: 0.1333
# Epoch 48/442
# 3/3 - 0s - loss: 3.3561 - accuracy: 0.1333
# Epoch 49/442
# 3/3 - 0s - loss: 3.3388 - accuracy: 0.1467
# Epoch 50/442
# 3/3 - 0s - loss: 3.3228 - accuracy: 0.1600
# Epoch 51/442
# 3/3 - 0s - loss: 3.3062 - accuracy: 0.1733
# Epoch 52/442
# 3/3 - 0s - loss: 3.2902 - accuracy: 0.1867
# Epoch 53/442
# 3/3 - 0s - loss: 3.2740 - accuracy: 0.2000
# Epoch 54/442
# 3/3 - 0s - loss: 3.2585 - accuracy: 0.2133
# Epoch 55/442
# 3/3 - 0s - loss: 3.2425 - accuracy: 0.2133
# Epoch 56/442
# 3/3 - 0s - loss: 3.2277 - accuracy: 0.2133
# Epoch 57/442
# 3/3 - 0s - loss: 3.2131 - accuracy: 0.2000
# Epoch 58/442
# 3/3 - 0s - loss: 3.1980 - accuracy: 0.1867
# Epoch 59/442
# 3/3 - 0s - loss: 3.1826 - accuracy: 0.2000
# Epoch 60/442
# 3/3 - 0s - loss: 3.1685 - accuracy: 0.1867
# Epoch 61/442
# 3/3 - 0s - loss: 3.1536 - accuracy: 0.1867
# Epoch 62/442
# 3/3 - 0s - loss: 3.1398 - accuracy: 0.1867
# Epoch 63/442
# 3/3 - 0s - loss: 3.1250 - accuracy: 0.2000
# Epoch 64/442
# 3/3 - 0s - loss: 3.1111 - accuracy: 0.2000
# Epoch 65/442
# 3/3 - 0s - loss: 3.0954 - accuracy: 0.2000
# Epoch 66/442
# 3/3 - 0s - loss: 3.0812 - accuracy: 0.2000
# Epoch 67/442
# 3/3 - 0s - loss: 3.0666 - accuracy: 0.2000
# Epoch 68/442
# 3/3 - 0s - loss: 3.0518 - accuracy: 0.2000
# Epoch 69/442
# 3/3 - 0s - loss: 3.0370 - accuracy: 0.2000
# Epoch 70/442
# 3/3 - 0s - loss: 3.0228 - accuracy: 0.2000
# Epoch 71/442
# 3/3 - 0s - loss: 3.0067 - accuracy: 0.2000
# Epoch 72/442
# 3/3 - 0s - loss: 2.9917 - accuracy: 0.2133
# Epoch 73/442
# 3/3 - 0s - loss: 2.9778 - accuracy: 0.2133
# Epoch 74/442
# 3/3 - 0s - loss: 2.9617 - accuracy: 0.2133
# Epoch 75/442
# 3/3 - 0s - loss: 2.9471 - accuracy: 0.2000
# Epoch 76/442
# 3/3 - 0s - loss: 2.9310 - accuracy: 0.2000
# Epoch 77/442
# 3/3 - 0s - loss: 2.9145 - accuracy: 0.2133
# Epoch 78/442
# 3/3 - 0s - loss: 2.8996 - accuracy: 0.2000
# Epoch 79/442
# 3/3 - 0s - loss: 2.8820 - accuracy: 0.2133
# Epoch 80/442
# 3/3 - 0s - loss: 2.8658 - accuracy: 0.2133
# Epoch 81/442
# 3/3 - 0s - loss: 2.8489 - accuracy: 0.2267
# Epoch 82/442
# 3/3 - 0s - loss: 2.8327 - accuracy: 0.2267
# Epoch 83/442
# 3/3 - 0s - loss: 2.8151 - accuracy: 0.2267
# Epoch 84/442
# 3/3 - 0s - loss: 2.7985 - accuracy: 0.2667
# Epoch 85/442
# 3/3 - 0s - loss: 2.7804 - accuracy: 0.2667
# Epoch 86/442
# 3/3 - 0s - loss: 2.7628 - accuracy: 0.2667
# Epoch 87/442
# 3/3 - 0s - loss: 2.7458 - accuracy: 0.2667
# Epoch 88/442
# 3/3 - 0s - loss: 2.7269 - accuracy: 0.2933
# Epoch 89/442
# 3/3 - 0s - loss: 2.7094 - accuracy: 0.3067
# Epoch 90/442
# 3/3 - 0s - loss: 2.6911 - accuracy: 0.3067
# Epoch 91/442
# 3/3 - 0s - loss: 2.6719 - accuracy: 0.3067
# Epoch 92/442
# 3/3 - 0s - loss: 2.6554 - accuracy: 0.3067
# Epoch 93/442
# 3/3 - 0s - loss: 2.6360 - accuracy: 0.3200
# Epoch 94/442
# 3/3 - 0s - loss: 2.6167 - accuracy: 0.3467
# Epoch 95/442
# 3/3 - 0s - loss: 2.5986 - accuracy: 0.3467
# Epoch 96/442
# 3/3 - 0s - loss: 2.5786 - accuracy: 0.3333
# Epoch 97/442
# 3/3 - 0s - loss: 2.5598 - accuracy: 0.3333
# Epoch 98/442
# 3/3 - 0s - loss: 2.5403 - accuracy: 0.3333
# Epoch 99/442
# 3/3 - 0s - loss: 2.5217 - accuracy: 0.3467
# Epoch 100/442
# 3/3 - 0s - loss: 2.5030 - accuracy: 0.3333
# Epoch 101/442
# 3/3 - 0s - loss: 2.4829 - accuracy: 0.3200
# Epoch 102/442
# 3/3 - 0s - loss: 2.4633 - accuracy: 0.3200
# Epoch 103/442
# 3/3 - 0s - loss: 2.4444 - accuracy: 0.3200
# Epoch 104/442
# 3/3 - 0s - loss: 2.4249 - accuracy: 0.3333
# Epoch 105/442
# 3/3 - 0s - loss: 2.4049 - accuracy: 0.3333
# Epoch 106/442
# 3/3 - 0s - loss: 2.3859 - accuracy: 0.3600
# Epoch 107/442
# 3/3 - 0s - loss: 2.3673 - accuracy: 0.3600
# Epoch 108/442
# 3/3 - 0s - loss: 2.3469 - accuracy: 0.3600
# Epoch 109/442
# 3/3 - 0s - loss: 2.3272 - accuracy: 0.3733
# Epoch 110/442
# 3/3 - 0s - loss: 2.3070 - accuracy: 0.3733
# Epoch 111/442
# 3/3 - 0s - loss: 2.2877 - accuracy: 0.3733
# Epoch 112/442
# 3/3 - 0s - loss: 2.2690 - accuracy: 0.3733
# Epoch 113/442
# 3/3 - 0s - loss: 2.2490 - accuracy: 0.3733
# Epoch 114/442
# 3/3 - 0s - loss: 2.2283 - accuracy: 0.4267
# Epoch 115/442
# 3/3 - 0s - loss: 2.2083 - accuracy: 0.4267
# Epoch 116/442
# 3/3 - 0s - loss: 2.1883 - accuracy: 0.4400
# Epoch 117/442
# 3/3 - 0s - loss: 2.1681 - accuracy: 0.4400
# Epoch 118/442
# 3/3 - 0s - loss: 2.1480 - accuracy: 0.4267
# Epoch 119/442
# 3/3 - 0s - loss: 2.1276 - accuracy: 0.4267
# Epoch 120/442
# 3/3 - 0s - loss: 2.1067 - accuracy: 0.4267
# Epoch 121/442
# 3/3 - 0s - loss: 2.0868 - accuracy: 0.4267
# Epoch 122/442
# 3/3 - 0s - loss: 2.0662 - accuracy: 0.4533
# Epoch 123/442
# 3/3 - 0s - loss: 2.0466 - accuracy: 0.4933
# Epoch 124/442
# 3/3 - 0s - loss: 2.0255 - accuracy: 0.4800
# Epoch 125/442
# 3/3 - 0s - loss: 2.0054 - accuracy: 0.4800
# Epoch 126/442
# 3/3 - 0s - loss: 1.9844 - accuracy: 0.4800
# Epoch 127/442
# 3/3 - 0s - loss: 1.9633 - accuracy: 0.4800
# Epoch 128/442
# 3/3 - 0s - loss: 1.9439 - accuracy: 0.4800
# Epoch 129/442
# 3/3 - 0s - loss: 1.9224 - accuracy: 0.4933
# Epoch 130/442
# 3/3 - 0s - loss: 1.9018 - accuracy: 0.4933
# Epoch 131/442
# 3/3 - 0s - loss: 1.8808 - accuracy: 0.5067
# Epoch 132/442
# 3/3 - 0s - loss: 1.8599 - accuracy: 0.5200
# Epoch 133/442
# 3/3 - 0s - loss: 1.8384 - accuracy: 0.5200
# Epoch 134/442
# 3/3 - 0s - loss: 1.8175 - accuracy: 0.5067
# Epoch 135/442
# 3/3 - 0s - loss: 1.7963 - accuracy: 0.5467
# Epoch 136/442
# 3/3 - 0s - loss: 1.7759 - accuracy: 0.5867
# Epoch 137/442
# 3/3 - 0s - loss: 1.7550 - accuracy: 0.5867
# Epoch 138/442
# 3/3 - 0s - loss: 1.7345 - accuracy: 0.5733
# Epoch 139/442
# 3/3 - 0s - loss: 1.7146 - accuracy: 0.5867
# Epoch 140/442
# 3/3 - 0s - loss: 1.6934 - accuracy: 0.5867
# Epoch 141/442
# 3/3 - 0s - loss: 1.6735 - accuracy: 0.6000
# Epoch 142/442
# 3/3 - 0s - loss: 1.6527 - accuracy: 0.6000
# Epoch 143/442
# 3/3 - 0s - loss: 1.6332 - accuracy: 0.5867
# Epoch 144/442
# 3/3 - 0s - loss: 1.6125 - accuracy: 0.6000
# Epoch 145/442
# 3/3 - 0s - loss: 1.5929 - accuracy: 0.6000
# Epoch 146/442
# 3/3 - 0s - loss: 1.5733 - accuracy: 0.6000
# Epoch 147/442
# 3/3 - 0s - loss: 1.5534 - accuracy: 0.6133
# Epoch 148/442
# 3/3 - 0s - loss: 1.5338 - accuracy: 0.6133
# Epoch 149/442
# 3/3 - 0s - loss: 1.5141 - accuracy: 0.6133
# Epoch 150/442
# 3/3 - 0s - loss: 1.4948 - accuracy: 0.6133
# Epoch 151/442
# 3/3 - 0s - loss: 1.4763 - accuracy: 0.6267
# Epoch 152/442
# 3/3 - 0s - loss: 1.4577 - accuracy: 0.6267
# Epoch 153/442
# 3/3 - 0s - loss: 1.4396 - accuracy: 0.6933
# Epoch 154/442
# 3/3 - 0s - loss: 1.4205 - accuracy: 0.7067
# Epoch 155/442
# 3/3 - 0s - loss: 1.4031 - accuracy: 0.7067
# Epoch 156/442
# 3/3 - 0s - loss: 1.3848 - accuracy: 0.7067
# Epoch 157/442
# 3/3 - 0s - loss: 1.3662 - accuracy: 0.7067
# Epoch 158/442
# 3/3 - 0s - loss: 1.3482 - accuracy: 0.6933
# Epoch 159/442
# 3/3 - 0s - loss: 1.3308 - accuracy: 0.7200
# Epoch 160/442
# 3/3 - 0s - loss: 1.3136 - accuracy: 0.7200
# Epoch 161/442
# 3/3 - 0s - loss: 1.2971 - accuracy: 0.7067
# Epoch 162/442
# 3/3 - 0s - loss: 1.2794 - accuracy: 0.7200
# Epoch 163/442
# 3/3 - 0s - loss: 1.2619 - accuracy: 0.7200
# Epoch 164/442
# 3/3 - 0s - loss: 1.2470 - accuracy: 0.7200
# Epoch 165/442
# 3/3 - 0s - loss: 1.2297 - accuracy: 0.7333
# Epoch 166/442
# 3/3 - 0s - loss: 1.2139 - accuracy: 0.7467
# Epoch 167/442
# 3/3 - 0s - loss: 1.1984 - accuracy: 0.7600
# Epoch 168/442
# 3/3 - 0s - loss: 1.1835 - accuracy: 0.7600
# Epoch 169/442
# 3/3 - 0s - loss: 1.1681 - accuracy: 0.7600
# Epoch 170/442
# 3/3 - 0s - loss: 1.1524 - accuracy: 0.7600
# Epoch 171/442
# 3/3 - 0s - loss: 1.1372 - accuracy: 0.7600
# Epoch 172/442
# 3/3 - 0s - loss: 1.1214 - accuracy: 0.7600
# Epoch 173/442
# 3/3 - 0s - loss: 1.1067 - accuracy: 0.7733
# Epoch 174/442
# 3/3 - 0s - loss: 1.0934 - accuracy: 0.7733
# Epoch 175/442
# 3/3 - 0s - loss: 1.0783 - accuracy: 0.7733
# Epoch 176/442
# 3/3 - 0s - loss: 1.0651 - accuracy: 0.7867
# Epoch 177/442
# 3/3 - 0s - loss: 1.0512 - accuracy: 0.7867
# Epoch 178/442
# 3/3 - 0s - loss: 1.0374 - accuracy: 0.8000
# Epoch 179/442
# 3/3 - 0s - loss: 1.0235 - accuracy: 0.8000
# Epoch 180/442
# 3/3 - 0s - loss: 1.0116 - accuracy: 0.8133
# Epoch 181/442
# 3/3 - 0s - loss: 0.9979 - accuracy: 0.8133
# Epoch 182/442
# 3/3 - 0s - loss: 0.9857 - accuracy: 0.8133
# Epoch 183/442
# 3/3 - 0s - loss: 0.9730 - accuracy: 0.8267
# Epoch 184/442
# 3/3 - 0s - loss: 0.9599 - accuracy: 0.8267
# Epoch 185/442
# 3/3 - 0s - loss: 0.9475 - accuracy: 0.8267
# Epoch 186/442
# 3/3 - 0s - loss: 0.9356 - accuracy: 0.8267
# Epoch 187/442
# 3/3 - 0s - loss: 0.9237 - accuracy: 0.8400
# Epoch 188/442
# 3/3 - 0s - loss: 0.9117 - accuracy: 0.8400
# Epoch 189/442
# 3/3 - 0s - loss: 0.9005 - accuracy: 0.8400
# Epoch 190/442
# 3/3 - 0s - loss: 0.8887 - accuracy: 0.8533
# Epoch 191/442
# 3/3 - 0s - loss: 0.8783 - accuracy: 0.8667
# Epoch 192/442
# 3/3 - 0s - loss: 0.8670 - accuracy: 0.8667
# Epoch 193/442
# 3/3 - 0s - loss: 0.8562 - accuracy: 0.8800
# Epoch 194/442
# 3/3 - 0s - loss: 0.8456 - accuracy: 0.8800
# Epoch 195/442
# 3/3 - 0s - loss: 0.8358 - accuracy: 0.8800
# Epoch 196/442
# 3/3 - 0s - loss: 0.8259 - accuracy: 0.8667
# Epoch 197/442
# 3/3 - 0s - loss: 0.8155 - accuracy: 0.8800
# Epoch 198/442
# 3/3 - 0s - loss: 0.8054 - accuracy: 0.8933
# Epoch 199/442
# 3/3 - 0s - loss: 0.7971 - accuracy: 0.8933
# Epoch 200/442
# 3/3 - 0s - loss: 0.7874 - accuracy: 0.9067
# Epoch 201/442
# 3/3 - 0s - loss: 0.7776 - accuracy: 0.9067
# Epoch 202/442
# 3/3 - 0s - loss: 0.7682 - accuracy: 0.9067
# Epoch 203/442
# 3/3 - 0s - loss: 0.7596 - accuracy: 0.9067
# Epoch 204/442
# 3/3 - 0s - loss: 0.7509 - accuracy: 0.9067
# Epoch 205/442
# 3/3 - 0s - loss: 0.7417 - accuracy: 0.8800
# Epoch 206/442
# 3/3 - 0s - loss: 0.7330 - accuracy: 0.8800
# Epoch 207/442
# 3/3 - 0s - loss: 0.7237 - accuracy: 0.8933
# Epoch 208/442
# 3/3 - 0s - loss: 0.7153 - accuracy: 0.9200
# Epoch 209/442
# 3/3 - 0s - loss: 0.7065 - accuracy: 0.9200
# Epoch 210/442
# 3/3 - 0s - loss: 0.6978 - accuracy: 0.9067
# Epoch 211/442
# 3/3 - 0s - loss: 0.6900 - accuracy: 0.9067
# Epoch 212/442
# 3/3 - 0s - loss: 0.6822 - accuracy: 0.9200
# Epoch 213/442
# 3/3 - 0s - loss: 0.6740 - accuracy: 0.9200
# Epoch 214/442
# 3/3 - 0s - loss: 0.6666 - accuracy: 0.9200
# Epoch 215/442
# 3/3 - 0s - loss: 0.6586 - accuracy: 0.9200
# Epoch 216/442
# 3/3 - 0s - loss: 0.6508 - accuracy: 0.9200
# Epoch 217/442
# 3/3 - 0s - loss: 0.6434 - accuracy: 0.9200
# Epoch 218/442
# 3/3 - 0s - loss: 0.6366 - accuracy: 0.9200
# Epoch 219/442
# 3/3 - 0s - loss: 0.6292 - accuracy: 0.9333
# Epoch 220/442
# 3/3 - 0s - loss: 0.6224 - accuracy: 0.9333
# Epoch 221/442
# 3/3 - 0s - loss: 0.6154 - accuracy: 0.9333
# Epoch 222/442
# 3/3 - 0s - loss: 0.6086 - accuracy: 0.9333
# Epoch 223/442
# 3/3 - 0s - loss: 0.6024 - accuracy: 0.9333
# Epoch 224/442
# 3/3 - 0s - loss: 0.5956 - accuracy: 0.9333
# Epoch 225/442
# 3/3 - 0s - loss: 0.5894 - accuracy: 0.9467
# Epoch 226/442
# 3/3 - 0s - loss: 0.5830 - accuracy: 0.9333
# Epoch 227/442
# 3/3 - 0s - loss: 0.5775 - accuracy: 0.9333
# Epoch 228/442
# 3/3 - 0s - loss: 0.5720 - accuracy: 0.9333
# Epoch 229/442
# 3/3 - 0s - loss: 0.5660 - accuracy: 0.9333
# Epoch 230/442
# 3/3 - 0s - loss: 0.5604 - accuracy: 0.9333
# Epoch 231/442
# 3/3 - 0s - loss: 0.5542 - accuracy: 0.9333
# Epoch 232/442
# 3/3 - 0s - loss: 0.5482 - accuracy: 0.9333
# Epoch 233/442
# 3/3 - 0s - loss: 0.5424 - accuracy: 0.9333
# Epoch 234/442
# 3/3 - 0s - loss: 0.5363 - accuracy: 0.9333
# Epoch 235/442
# 3/3 - 0s - loss: 0.5306 - accuracy: 0.9333
# Epoch 236/442
# 3/3 - 0s - loss: 0.5246 - accuracy: 0.9333
# Epoch 237/442
# 3/3 - 0s - loss: 0.5192 - accuracy: 0.9333
# Epoch 238/442
# 3/3 - 0s - loss: 0.5145 - accuracy: 0.9467
# Epoch 239/442
# 3/3 - 0s - loss: 0.5094 - accuracy: 0.9467
# Epoch 240/442
# 3/3 - 0s - loss: 0.5044 - accuracy: 0.9467
# Epoch 241/442
# 3/3 - 0s - loss: 0.4991 - accuracy: 0.9467
# Epoch 242/442
# 3/3 - 0s - loss: 0.4939 - accuracy: 0.9467
# Epoch 243/442
# 3/3 - 0s - loss: 0.4888 - accuracy: 0.9467
# Epoch 244/442
# 3/3 - 0s - loss: 0.4840 - accuracy: 0.9467
# Epoch 245/442
# 3/3 - 0s - loss: 0.4788 - accuracy: 0.9467
# Epoch 246/442
# 3/3 - 0s - loss: 0.4745 - accuracy: 0.9467
# Epoch 247/442
# 3/3 - 0s - loss: 0.4694 - accuracy: 0.9467
# Epoch 248/442
# 3/3 - 0s - loss: 0.4646 - accuracy: 0.9467
# Epoch 249/442
# 3/3 - 0s - loss: 0.4606 - accuracy: 0.9467
# Epoch 250/442
# 3/3 - 0s - loss: 0.4562 - accuracy: 0.9467
# Epoch 251/442
# 3/3 - 0s - loss: 0.4515 - accuracy: 0.9467
# Epoch 252/442
# 3/3 - 0s - loss: 0.4469 - accuracy: 0.9467
# Epoch 253/442
# 3/3 - 0s - loss: 0.4430 - accuracy: 0.9467
# Epoch 254/442
# 3/3 - 0s - loss: 0.4387 - accuracy: 0.9467
# Epoch 255/442
# 3/3 - 0s - loss: 0.4350 - accuracy: 0.9467
# Epoch 256/442
# 3/3 - 0s - loss: 0.4300 - accuracy: 0.9467
# Epoch 257/442
# 3/3 - 0s - loss: 0.4259 - accuracy: 0.9467
# Epoch 258/442
# 3/3 - 0s - loss: 0.4225 - accuracy: 0.9467
# Epoch 259/442
# 3/3 - 0s - loss: 0.4184 - accuracy: 0.9467
# Epoch 260/442
# 3/3 - 0s - loss: 0.4143 - accuracy: 0.9467
# Epoch 261/442
# 3/3 - 0s - loss: 0.4101 - accuracy: 0.9467
# Epoch 262/442
# 3/3 - 0s - loss: 0.4071 - accuracy: 0.9467
# Epoch 263/442
# 3/3 - 0s - loss: 0.4035 - accuracy: 0.9467
# Epoch 264/442
# 3/3 - 0s - loss: 0.3999 - accuracy: 0.9467
# Epoch 265/442
# 3/3 - 0s - loss: 0.3965 - accuracy: 0.9467
# Epoch 266/442
# 3/3 - 0s - loss: 0.3926 - accuracy: 0.9333
# Epoch 267/442
# 3/3 - 0s - loss: 0.3885 - accuracy: 0.9467
# Epoch 268/442
# 3/3 - 0s - loss: 0.3849 - accuracy: 0.9467
# Epoch 269/442
# 3/3 - 0s - loss: 0.3808 - accuracy: 0.9467
# Epoch 270/442
# 3/3 - 0s - loss: 0.3782 - accuracy: 0.9467
# Epoch 271/442
# 3/3 - 0s - loss: 0.3737 - accuracy: 0.9467
# Epoch 272/442
# 3/3 - 0s - loss: 0.3705 - accuracy: 0.9467
# Epoch 273/442
# 3/3 - 0s - loss: 0.3678 - accuracy: 0.9467
# Epoch 274/442
# 3/3 - 0s - loss: 0.3647 - accuracy: 0.9467
# Epoch 275/442
# 3/3 - 0s - loss: 0.3622 - accuracy: 0.9467
# Epoch 276/442
# 3/3 - 0s - loss: 0.3586 - accuracy: 0.9467
# Epoch 277/442
# 3/3 - 0s - loss: 0.3555 - accuracy: 0.9467
# Epoch 278/442
# 3/3 - 0s - loss: 0.3521 - accuracy: 0.9467
# Epoch 279/442
# 3/3 - 0s - loss: 0.3488 - accuracy: 0.9467
# Epoch 280/442
# 3/3 - 0s - loss: 0.3459 - accuracy: 0.9467
# Epoch 281/442
# 3/3 - 0s - loss: 0.3425 - accuracy: 0.9467
# Epoch 282/442
# 3/3 - 0s - loss: 0.3394 - accuracy: 0.9467
# Epoch 283/442
# 3/3 - 0s - loss: 0.3369 - accuracy: 0.9467
# Epoch 284/442
# 3/3 - 0s - loss: 0.3342 - accuracy: 0.9467
# Epoch 285/442
# 3/3 - 0s - loss: 0.3311 - accuracy: 0.9467
# Epoch 286/442
# 3/3 - 0s - loss: 0.3286 - accuracy: 0.9467
# Epoch 287/442
# 3/3 - 0s - loss: 0.3259 - accuracy: 0.9467
# Epoch 288/442
# 3/3 - 0s - loss: 0.3228 - accuracy: 0.9467
# Epoch 289/442
# 3/3 - 0s - loss: 0.3214 - accuracy: 0.9467
# Epoch 290/442
# 3/3 - 0s - loss: 0.3181 - accuracy: 0.9467
# Epoch 291/442
# 3/3 - 0s - loss: 0.3162 - accuracy: 0.9467
# Epoch 292/442
# 3/3 - 0s - loss: 0.3135 - accuracy: 0.9467
# Epoch 293/442
# 3/3 - 0s - loss: 0.3113 - accuracy: 0.9467
# Epoch 294/442
# 3/3 - 0s - loss: 0.3084 - accuracy: 0.9467
# Epoch 295/442
# 3/3 - 0s - loss: 0.3061 - accuracy: 0.9467
# Epoch 296/442
# 3/3 - 0s - loss: 0.3042 - accuracy: 0.9467
# Epoch 297/442
# 3/3 - 0s - loss: 0.3014 - accuracy: 0.9467
# Epoch 298/442
# 3/3 - 0s - loss: 0.2990 - accuracy: 0.9467
# Epoch 299/442
# 3/3 - 0s - loss: 0.2973 - accuracy: 0.9467
# Epoch 300/442
# 3/3 - 0s - loss: 0.2946 - accuracy: 0.9467
# Epoch 301/442
# 3/3 - 0s - loss: 0.2928 - accuracy: 0.9467
# Epoch 302/442
# 3/3 - 0s - loss: 0.2903 - accuracy: 0.9467
# Epoch 303/442
# 3/3 - 0s - loss: 0.2891 - accuracy: 0.9467
# Epoch 304/442
# 3/3 - 0s - loss: 0.2867 - accuracy: 0.9467
# Epoch 305/442
# 3/3 - 0s - loss: 0.2843 - accuracy: 0.9467
# Epoch 306/442
# 3/3 - 0s - loss: 0.2823 - accuracy: 0.9467
# Epoch 307/442
# 3/3 - 0s - loss: 0.2798 - accuracy: 0.9467
# Epoch 308/442
# 3/3 - 0s - loss: 0.2776 - accuracy: 0.9467
# Epoch 309/442
# 3/3 - 0s - loss: 0.2760 - accuracy: 0.9467
# Epoch 310/442
# 3/3 - 0s - loss: 0.2740 - accuracy: 0.9467
# Epoch 311/442
# 3/3 - 0s - loss: 0.2717 - accuracy: 0.9467
# Epoch 312/442
# 3/3 - 0s - loss: 0.2694 - accuracy: 0.9467
# Epoch 313/442
# 3/3 - 0s - loss: 0.2690 - accuracy: 0.9467
# Epoch 314/442
# 3/3 - 0s - loss: 0.2665 - accuracy: 0.9467
# Epoch 315/442
# 3/3 - 0s - loss: 0.2647 - accuracy: 0.9467
# Epoch 316/442
# 3/3 - 0s - loss: 0.2628 - accuracy: 0.9467
# Epoch 317/442
# 3/3 - 0s - loss: 0.2612 - accuracy: 0.9467
# Epoch 318/442
# 3/3 - 0s - loss: 0.2593 - accuracy: 0.9467
# Epoch 319/442
# 3/3 - 0s - loss: 0.2575 - accuracy: 0.9600
# Epoch 320/442
# 3/3 - 0s - loss: 0.2561 - accuracy: 0.9600
# Epoch 321/442
# 3/3 - 0s - loss: 0.2545 - accuracy: 0.9600
# Epoch 322/442
# 3/3 - 0s - loss: 0.2528 - accuracy: 0.9600
# Epoch 323/442
# 3/3 - 0s - loss: 0.2511 - accuracy: 0.9600
# Epoch 324/442
# 3/3 - 0s - loss: 0.2493 - accuracy: 0.9600
# Epoch 325/442
# 3/3 - 0s - loss: 0.2480 - accuracy: 0.9600
# Epoch 326/442
# 3/3 - 0s - loss: 0.2462 - accuracy: 0.9600
# Epoch 327/442
# 3/3 - 0s - loss: 0.2440 - accuracy: 0.9600
# Epoch 328/442
# 3/3 - 0s - loss: 0.2427 - accuracy: 0.9600
# Epoch 329/442
# 3/3 - 0s - loss: 0.2413 - accuracy: 0.9600
# Epoch 330/442
# 3/3 - 0s - loss: 0.2397 - accuracy: 0.9600
# Epoch 331/442
# 3/3 - 0s - loss: 0.2385 - accuracy: 0.9600
# Epoch 332/442
# 3/3 - 0s - loss: 0.2367 - accuracy: 0.9600
# Epoch 333/442
# 3/3 - 0s - loss: 0.2353 - accuracy: 0.9600
# Epoch 334/442
# 3/3 - 0s - loss: 0.2338 - accuracy: 0.9600
# Epoch 335/442
# 3/3 - 0s - loss: 0.2321 - accuracy: 0.9600
# Epoch 336/442
# 3/3 - 0s - loss: 0.2304 - accuracy: 0.9600
# Epoch 337/442
# 3/3 - 0s - loss: 0.2293 - accuracy: 0.9600
# Epoch 338/442
# 3/3 - 0s - loss: 0.2277 - accuracy: 0.9600
# Epoch 339/442
# 3/3 - 0s - loss: 0.2266 - accuracy: 0.9600
# Epoch 340/442
# 3/3 - 0s - loss: 0.2253 - accuracy: 0.9600
# Epoch 341/442
# 3/3 - 0s - loss: 0.2233 - accuracy: 0.9600
# Epoch 342/442
# 3/3 - 0s - loss: 0.2218 - accuracy: 0.9600
# Epoch 343/442
# 3/3 - 0s - loss: 0.2201 - accuracy: 0.9600
# Epoch 344/442
# 3/3 - 0s - loss: 0.2202 - accuracy: 0.9600
# Epoch 345/442
# 3/3 - 0s - loss: 0.2190 - accuracy: 0.9600
# Epoch 346/442
# 3/3 - 0s - loss: 0.2176 - accuracy: 0.9600
# Epoch 347/442
# 3/3 - 0s - loss: 0.2161 - accuracy: 0.9600
# Epoch 348/442
# 3/3 - 0s - loss: 0.2147 - accuracy: 0.9600
# Epoch 349/442
# 3/3 - 0s - loss: 0.2129 - accuracy: 0.9600
# Epoch 350/442
# 3/3 - 0s - loss: 0.2116 - accuracy: 0.9600
# Epoch 351/442
# 3/3 - 0s - loss: 0.2118 - accuracy: 0.9600
# Epoch 352/442
# 3/3 - 0s - loss: 0.2098 - accuracy: 0.9600
# Epoch 353/442
# 3/3 - 0s - loss: 0.2086 - accuracy: 0.9600
# Epoch 354/442
# 3/3 - 0s - loss: 0.2073 - accuracy: 0.9600
# Epoch 355/442
# 3/3 - 0s - loss: 0.2065 - accuracy: 0.9600
# Epoch 356/442
# 3/3 - 0s - loss: 0.2050 - accuracy: 0.9600
# Epoch 357/442
# 3/3 - 0s - loss: 0.2039 - accuracy: 0.9600
# Epoch 358/442
# 3/3 - 0s - loss: 0.2031 - accuracy: 0.9600
# Epoch 359/442
# 3/3 - 0s - loss: 0.2018 - accuracy: 0.9600
# Epoch 360/442
# 3/3 - 0s - loss: 0.2008 - accuracy: 0.9600
# Epoch 361/442
# 3/3 - 0s - loss: 0.1995 - accuracy: 0.9600
# Epoch 362/442
# 3/3 - 0s - loss: 0.1980 - accuracy: 0.9600
# Epoch 363/442
# 3/3 - 0s - loss: 0.1968 - accuracy: 0.9600
# Epoch 364/442
# 3/3 - 0s - loss: 0.1955 - accuracy: 0.9600
# Epoch 365/442
# 3/3 - 0s - loss: 0.1944 - accuracy: 0.9600
# Epoch 366/442
# 3/3 - 0s - loss: 0.1939 - accuracy: 0.9600
# Epoch 367/442
# 3/3 - 0s - loss: 0.1926 - accuracy: 0.9600
# Epoch 368/442
# 3/3 - 0s - loss: 0.1916 - accuracy: 0.9600
# Epoch 369/442
# 3/3 - 0s - loss: 0.1907 - accuracy: 0.9600
# Epoch 370/442
# 3/3 - 0s - loss: 0.1896 - accuracy: 0.9600
# Epoch 371/442
# 3/3 - 0s - loss: 0.1888 - accuracy: 0.9600
# Epoch 372/442
# 3/3 - 0s - loss: 0.1876 - accuracy: 0.9600
# Epoch 373/442
# 3/3 - 0s - loss: 0.1872 - accuracy: 0.9600
# Epoch 374/442
# 3/3 - 0s - loss: 0.1865 - accuracy: 0.9600
# Epoch 375/442
# 3/3 - 0s - loss: 0.1857 - accuracy: 0.9600
# Epoch 376/442
# 3/3 - 0s - loss: 0.1844 - accuracy: 0.9600
# Epoch 377/442
# 3/3 - 0s - loss: 0.1835 - accuracy: 0.9600
# Epoch 378/442
# 3/3 - 0s - loss: 0.1825 - accuracy: 0.9600
# Epoch 379/442
# 3/3 - 0s - loss: 0.1816 - accuracy: 0.9600
# Epoch 380/442
# 3/3 - 0s - loss: 0.1810 - accuracy: 0.9600
# Epoch 381/442
# 3/3 - 0s - loss: 0.1795 - accuracy: 0.9600
# Epoch 382/442
# 3/3 - 0s - loss: 0.1790 - accuracy: 0.9600
# Epoch 383/442
# 3/3 - 0s - loss: 0.1779 - accuracy: 0.9600
# Epoch 384/442
# 3/3 - 0s - loss: 0.1770 - accuracy: 0.9600
# Epoch 385/442
# 3/3 - 0s - loss: 0.1764 - accuracy: 0.9600
# Epoch 386/442
# 3/3 - 0s - loss: 0.1751 - accuracy: 0.9600
# Epoch 387/442
# 3/3 - 0s - loss: 0.1741 - accuracy: 0.9600
# Epoch 388/442
# 3/3 - 0s - loss: 0.1733 - accuracy: 0.9600
# Epoch 389/442
# 3/3 - 0s - loss: 0.1721 - accuracy: 0.9600
# Epoch 390/442
# 3/3 - 0s - loss: 0.1714 - accuracy: 0.9600
# Epoch 391/442
# 3/3 - 0s - loss: 0.1710 - accuracy: 0.9467
# Epoch 392/442
# 3/3 - 0s - loss: 0.1698 - accuracy: 0.9600
# Epoch 393/442
# 3/3 - 0s - loss: 0.1695 - accuracy: 0.9600
# Epoch 394/442
# 3/3 - 0s - loss: 0.1685 - accuracy: 0.9600
# Epoch 395/442
# 3/3 - 0s - loss: 0.1675 - accuracy: 0.9600
# Epoch 396/442
# 3/3 - 0s - loss: 0.1670 - accuracy: 0.9600
# Epoch 397/442
# 3/3 - 0s - loss: 0.1665 - accuracy: 0.9600
# Epoch 398/442
# 3/3 - 0s - loss: 0.1661 - accuracy: 0.9600
# Epoch 399/442
# 3/3 - 0s - loss: 0.1652 - accuracy: 0.9600
# Epoch 400/442
# 3/3 - 0s - loss: 0.1644 - accuracy: 0.9600
# Epoch 401/442
# 3/3 - 0s - loss: 0.1639 - accuracy: 0.9600
# Epoch 402/442
# 3/3 - 0s - loss: 0.1627 - accuracy: 0.9600
# Epoch 403/442
# 3/3 - 0s - loss: 0.1625 - accuracy: 0.9600
# Epoch 404/442
# 3/3 - 0s - loss: 0.1612 - accuracy: 0.9600
# Epoch 405/442
# 3/3 - 0s - loss: 0.1605 - accuracy: 0.9600
# Epoch 406/442
# 3/3 - 0s - loss: 0.1601 - accuracy: 0.9600
# Epoch 407/442
# 3/3 - 0s - loss: 0.1593 - accuracy: 0.9467
# Epoch 408/442
# 3/3 - 0s - loss: 0.1586 - accuracy: 0.9600
# Epoch 409/442
# 3/3 - 0s - loss: 0.1581 - accuracy: 0.9600
# Epoch 410/442
# 3/3 - 0s - loss: 0.1574 - accuracy: 0.9600
# Epoch 411/442
# 3/3 - 0s - loss: 0.1565 - accuracy: 0.9600
# Epoch 412/442
# 3/3 - 0s - loss: 0.1558 - accuracy: 0.9600
# Epoch 413/442
# 3/3 - 0s - loss: 0.1549 - accuracy: 0.9600
# Epoch 414/442
# 3/3 - 0s - loss: 0.1545 - accuracy: 0.9600
# Epoch 415/442
# 3/3 - 0s - loss: 0.1539 - accuracy: 0.9600
# Epoch 416/442
# 3/3 - 0s - loss: 0.1534 - accuracy: 0.9600
# Epoch 417/442
# 3/3 - 0s - loss: 0.1528 - accuracy: 0.9600
# Epoch 418/442
# 3/3 - 0s - loss: 0.1523 - accuracy: 0.9600
# Epoch 419/442
# 3/3 - 0s - loss: 0.1516 - accuracy: 0.9600
# Epoch 420/442
# 3/3 - 0s - loss: 0.1510 - accuracy: 0.9600
# Epoch 421/442
# 3/3 - 0s - loss: 0.1502 - accuracy: 0.9600
# Epoch 422/442
# 3/3 - 0s - loss: 0.1498 - accuracy: 0.9600
# Epoch 423/442
# 3/3 - 0s - loss: 0.1489 - accuracy: 0.9600
# Epoch 424/442
# 3/3 - 0s - loss: 0.1484 - accuracy: 0.9600
# Epoch 425/442
# 3/3 - 0s - loss: 0.1482 - accuracy: 0.9467
# Epoch 426/442
# 3/3 - 0s - loss: 0.1471 - accuracy: 0.9600
# Epoch 427/442
# 3/3 - 0s - loss: 0.1470 - accuracy: 0.9600
# Epoch 428/442
# 3/3 - 0s - loss: 0.1460 - accuracy: 0.9600
# Epoch 429/442
# 3/3 - 0s - loss: 0.1455 - accuracy: 0.9600
# Epoch 430/442
# 3/3 - 0s - loss: 0.1452 - accuracy: 0.9600
# Epoch 431/442
# 3/3 - 0s - loss: 0.1447 - accuracy: 0.9600
# Epoch 432/442
# 3/3 - 0s - loss: 0.1439 - accuracy: 0.9600
# Epoch 433/442
# 3/3 - 0s - loss: 0.1435 - accuracy: 0.9600
# Epoch 434/442
# 3/3 - 0s - loss: 0.1442 - accuracy: 0.9600
# Epoch 435/442
# 3/3 - 0s - loss: 0.1433 - accuracy: 0.9600
# Epoch 436/442
# 3/3 - 0s - loss: 0.1429 - accuracy: 0.9600
# Epoch 437/442
# 3/3 - 0s - loss: 0.1425 - accuracy: 0.9600
# Epoch 438/442
# 3/3 - 0s - loss: 0.1416 - accuracy: 0.9600
# Epoch 439/442
# 3/3 - 0s - loss: 0.1411 - accuracy: 0.9600
# Epoch 440/442
# 3/3 - 0s - loss: 0.1406 - accuracy: 0.9600
# Epoch 441/442
# 3/3 - 0s - loss: 0.1400 - accuracy: 0.9600
# Epoch 442/442
# 3/3 - 0s - loss: 0.1394 - accuracy: 0.9600

# %%
# test start of rhyme
print(generate_seq(model, tokenizer, max_length-1, 'Sing a son', 3))
# test mid-line
print(generate_seq(model, tokenizer, max_length-1, 'king was i', 3))
# test not in original
#print(generate_seq(model, mapping, 10, 'hello worl', 1))
# Out:
# WARNING:tensorflow:From <ipython-input-2-8cf2911ad087>:11: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# Sing a son song of sixpence
# king was i in the parlour

# %% [markdown]
# In summary, what worked was any way to reduce the code down. In this case, using Tokenizer, encoding the words to numerical values, avoiding manually adjusting sequence length parameters, increasing epochs and adjusting the LSTM layer parameters.

# %% [markdown]
# # Line-by-Line Sequencing
#
# This alternate approach allows the model to use each line's context to help model cases of word ambiguity in the from the input sequence.
#
# The cost is that words are predicted across lines.
#
# This model uses sequence padding to ensure a fixed length input.

# %%
# generate a sequence from a language model
def generate_seq(model, tokenizer, max_length, seed_text, n_words):
	in_text = seed_text
	# generate a fixed number of words
	for _ in range(n_words):
		# encode the text as integer
		encoded = tokenizer.texts_to_sequences([in_text])[0]
		# pre-pad sequences to a fixed length
		encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')
		# predict probabilities for each word
		yhat = model.predict_classes(encoded, verbose=0)
		# map predicted word index to word
		out_word = ''
		for word, index in tokenizer.word_index.items():
			if index == yhat:
				out_word = word
				break
		# append to input
		in_text += ' ' + out_word
	return in_text

# %% [markdown]
# The generate_seq() function can be updated to build up an input sequence by adding predictions to the list of input words with each iteration.

# %%
# source text
data = """ Well here we are again
It's always such a pleasure
Remember when you tried
to kill me twice?

Oh how we laughed and laughed
Except I wasn't laughing
Under the circumstances
I've been shockingly nice

You want your freedom?
Take it
That's what I'm counting on
I used to want you dead
but
Now I only want you gone

She was a lot like you
(Maybe not quite as heavy)
Now little Caroline is in here too

One day they woke me up
So I could live forever
It's such a shame the same
will never happen to you

You've got your
short sad life left
That's what I'm counting on
I'll let you get right to it
Now I only want you gone

Goodbye my only friend
Oh, did you think I meant you?
That would be funny
if it weren't so sad

Well you have been replaced
I don't need anyone now
When I delete you maybe
I'll stop feeling so bad

Go make some new disaster
That's what I'm counting on
You're someone else's problem
Now I only want you gone
Now I only want you gone
Now I only want you gone"""

# %%
# prepare the tokenizer on the source text
tokenizer = Tokenizer()
tokenizer.fit_on_texts([data])
# determine the vocabulary size
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# Out:
# Vocabulary Size: 118

# %%
# create line-based sequences
sequences = list()
for line in data.split('\n'):
	encoded = tokenizer.texts_to_sequences([line])[0]
	for i in range(1, len(encoded)):
		sequence = encoded[:i+1]
		sequences.append(sequence)
print('Total Sequences: %d' % len(sequences))
# Out:
# Total Sequences: 156

# %%
# pad input sequences
max_length = max([len(seq) for seq in sequences])
sequences = pad_sequences(sequences, maxlen=max_length, padding='pre')
print('Max Sequence Length: %d' % max_length)
# Out:
# Max Sequence Length: 7

# %%
# split into input and output elements
sequences = array(sequences)
X, y = sequences[:,:-1],sequences[:,-1]
y = to_categorical(y, num_classes=vocab_size)

# define model
model = Sequential()
model.add(Embedding(vocab_size, 10, input_length=max_length-1))
model.add(LSTM(50))
model.add(Dense(vocab_size, activation='softmax'))
print(model.summary())
# compile network
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit network
model.fit(X, y, epochs=500, verbose=2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 6, 10)             1180
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                12200
# _________________________________________________________________
# dense_1 (Dense)              (None, 118)               6018
# =================================================================
# Total params: 19,398
# Trainable params: 19,398
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/500
# 5/5 - 0s - loss: 4.7709 - accuracy: 0.0000e+00
# Epoch 2/500
# 5/5 - 0s - loss: 4.7655 - accuracy: 0.0449
# Epoch 3/500
# 5/5 - 0s - loss: 4.7598 - accuracy: 0.0897
# Epoch 4/500
# 5/5 - 0s - loss: 4.7532 - accuracy: 0.0897
# Epoch 5/500
# 5/5 - 0s - loss: 4.7443 - accuracy: 0.0897
# Epoch 6/500
# 5/5 - 0s - loss: 4.7314 - accuracy: 0.0897
# Epoch 7/500
# 5/5 - 0s - loss: 4.7133 - accuracy: 0.0897
# Epoch 8/500
# 5/5 - 0s - loss: 4.6820 - accuracy: 0.0897
# Epoch 9/500
# 5/5 - 0s - loss: 4.6353 - accuracy: 0.0897
# Epoch 10/500
# 5/5 - 0s - loss: 4.5485 - accuracy: 0.0897
# Epoch 11/500
# 5/5 - 0s - loss: 4.4384 - accuracy: 0.0897
# Epoch 12/500
# 5/5 - 0s - loss: 4.3384 - accuracy: 0.0897
# Epoch 13/500
# 5/5 - 0s - loss: 4.3231 - accuracy: 0.0897
# Epoch 14/500
# 5/5 - 0s - loss: 4.2985 - accuracy: 0.0897
# Epoch 15/500
# 5/5 - 0s - loss: 4.2710 - accuracy: 0.0897
# Epoch 16/500
# 5/5 - 0s - loss: 4.2564 - accuracy: 0.0897
# Epoch 17/500
# 5/5 - 0s - loss: 4.2449 - accuracy: 0.0897
# Epoch 18/500
# 5/5 - 0s - loss: 4.2337 - accuracy: 0.0897
# Epoch 19/500
# 5/5 - 0s - loss: 4.2241 - accuracy: 0.0897
# Epoch 20/500
# 5/5 - 0s - loss: 4.2136 - accuracy: 0.0897
# Epoch 21/500
# 5/5 - 0s - loss: 4.2019 - accuracy: 0.0897
# Epoch 22/500
# 5/5 - 0s - loss: 4.1912 - accuracy: 0.0897
# Epoch 23/500
# 5/5 - 0s - loss: 4.1774 - accuracy: 0.0897
# Epoch 24/500
# 5/5 - 0s - loss: 4.1643 - accuracy: 0.0897
# Epoch 25/500
# 5/5 - 0s - loss: 4.1507 - accuracy: 0.0897
# Epoch 26/500
# 5/5 - 0s - loss: 4.1380 - accuracy: 0.0897
# Epoch 27/500
# 5/5 - 0s - loss: 4.1208 - accuracy: 0.0897
# Epoch 28/500
# 5/5 - 0s - loss: 4.1068 - accuracy: 0.0897
# Epoch 29/500
# 5/5 - 0s - loss: 4.0884 - accuracy: 0.0897
# Epoch 30/500
# 5/5 - 0s - loss: 4.0702 - accuracy: 0.0897
# Epoch 31/500
# 5/5 - 0s - loss: 4.0523 - accuracy: 0.0897
# Epoch 32/500
# 5/5 - 0s - loss: 4.0335 - accuracy: 0.0897
# Epoch 33/500
# 5/5 - 0s - loss: 4.0156 - accuracy: 0.0897
# Epoch 34/500
# 5/5 - 0s - loss: 3.9958 - accuracy: 0.0897
# Epoch 35/500
# 5/5 - 0s - loss: 3.9768 - accuracy: 0.0897
# Epoch 36/500
# 5/5 - 0s - loss: 3.9572 - accuracy: 0.0897
# Epoch 37/500
# 5/5 - 0s - loss: 3.9352 - accuracy: 0.0897
# Epoch 38/500
# 5/5 - 0s - loss: 3.9126 - accuracy: 0.1026
# Epoch 39/500
# 5/5 - 0s - loss: 3.8917 - accuracy: 0.1154
# Epoch 40/500
# 5/5 - 0s - loss: 3.8665 - accuracy: 0.1410
# Epoch 41/500
# 5/5 - 0s - loss: 3.8433 - accuracy: 0.1282
# Epoch 42/500
# 5/5 - 0s - loss: 3.8163 - accuracy: 0.1282
# Epoch 43/500
# 5/5 - 0s - loss: 3.7918 - accuracy: 0.1282
# Epoch 44/500
# 5/5 - 0s - loss: 3.7668 - accuracy: 0.1346
# Epoch 45/500
# 5/5 - 0s - loss: 3.7386 - accuracy: 0.1474
# Epoch 46/500
# 5/5 - 0s - loss: 3.7124 - accuracy: 0.1474
# Epoch 47/500
# 5/5 - 0s - loss: 3.6894 - accuracy: 0.1474
# Epoch 48/500
# 5/5 - 0s - loss: 3.6582 - accuracy: 0.1474
# Epoch 49/500
# 5/5 - 0s - loss: 3.6344 - accuracy: 0.1538
# Epoch 50/500
# 5/5 - 0s - loss: 3.6032 - accuracy: 0.1667
# Epoch 51/500
# 5/5 - 0s - loss: 3.5812 - accuracy: 0.1474
# Epoch 52/500
# 5/5 - 0s - loss: 3.5545 - accuracy: 0.1731
# Epoch 53/500
# 5/5 - 0s - loss: 3.5234 - accuracy: 0.1731
# Epoch 54/500
# 5/5 - 0s - loss: 3.4962 - accuracy: 0.1795
# Epoch 55/500
# 5/5 - 0s - loss: 3.4641 - accuracy: 0.1859
# Epoch 56/500
# 5/5 - 0s - loss: 3.4390 - accuracy: 0.1795
# Epoch 57/500
# 5/5 - 0s - loss: 3.4182 - accuracy: 0.1923
# Epoch 58/500
# 5/5 - 0s - loss: 3.3814 - accuracy: 0.1859
# Epoch 59/500
# 5/5 - 0s - loss: 3.3544 - accuracy: 0.1859
# Epoch 60/500
# 5/5 - 0s - loss: 3.3238 - accuracy: 0.1859
# Epoch 61/500
# 5/5 - 0s - loss: 3.2905 - accuracy: 0.1859
# Epoch 62/500
# 5/5 - 0s - loss: 3.2619 - accuracy: 0.1859
# Epoch 63/500
# 5/5 - 0s - loss: 3.2326 - accuracy: 0.1923
# Epoch 64/500
# 5/5 - 0s - loss: 3.2104 - accuracy: 0.2179
# Epoch 65/500
# 5/5 - 0s - loss: 3.1682 - accuracy: 0.2564
# Epoch 66/500
# 5/5 - 0s - loss: 3.1385 - accuracy: 0.2692
# Epoch 67/500
# 5/5 - 0s - loss: 3.1077 - accuracy: 0.2756
# Epoch 68/500
# 5/5 - 0s - loss: 3.0766 - accuracy: 0.2885
# Epoch 69/500
# 5/5 - 0s - loss: 3.0488 - accuracy: 0.2821
# Epoch 70/500
# 5/5 - 0s - loss: 3.0149 - accuracy: 0.2885
# Epoch 71/500
# 5/5 - 0s - loss: 2.9811 - accuracy: 0.3013
# Epoch 72/500
# 5/5 - 0s - loss: 2.9569 - accuracy: 0.2885
# Epoch 73/500
# 5/5 - 0s - loss: 2.9361 - accuracy: 0.3077
# Epoch 74/500
# 5/5 - 0s - loss: 2.9016 - accuracy: 0.3077
# Epoch 75/500
# 5/5 - 0s - loss: 2.8680 - accuracy: 0.3077
# Epoch 76/500
# 5/5 - 0s - loss: 2.8439 - accuracy: 0.3013
# Epoch 77/500
# 5/5 - 0s - loss: 2.8163 - accuracy: 0.2949
# Epoch 78/500
# 5/5 - 0s - loss: 2.7900 - accuracy: 0.3077
# Epoch 79/500
# 5/5 - 0s - loss: 2.7615 - accuracy: 0.3141
# Epoch 80/500
# 5/5 - 0s - loss: 2.7307 - accuracy: 0.3141
# Epoch 81/500
# 5/5 - 0s - loss: 2.7165 - accuracy: 0.3205
# Epoch 82/500
# 5/5 - 0s - loss: 2.6842 - accuracy: 0.3590
# Epoch 83/500
# 5/5 - 0s - loss: 2.6595 - accuracy: 0.3462
# Epoch 84/500
# 5/5 - 0s - loss: 2.6316 - accuracy: 0.3397
# Epoch 85/500
# 5/5 - 0s - loss: 2.6138 - accuracy: 0.3654
# Epoch 86/500
# 5/5 - 0s - loss: 2.6097 - accuracy: 0.3526
# Epoch 87/500
# 5/5 - 0s - loss: 2.5811 - accuracy: 0.3654
# Epoch 88/500
# 5/5 - 0s - loss: 2.5424 - accuracy: 0.4038
# Epoch 89/500
# 5/5 - 0s - loss: 2.5171 - accuracy: 0.3974
# Epoch 90/500
# 5/5 - 0s - loss: 2.4894 - accuracy: 0.3974
# Epoch 91/500
# 5/5 - 0s - loss: 2.4796 - accuracy: 0.4231
# Epoch 92/500
# 5/5 - 0s - loss: 2.4541 - accuracy: 0.4423
# Epoch 93/500
# 5/5 - 0s - loss: 2.4306 - accuracy: 0.4167
# Epoch 94/500
# 5/5 - 0s - loss: 2.4048 - accuracy: 0.4359
# Epoch 95/500
# 5/5 - 0s - loss: 2.3843 - accuracy: 0.4679
# Epoch 96/500
# 5/5 - 0s - loss: 2.3628 - accuracy: 0.4423
# Epoch 97/500
# 5/5 - 0s - loss: 2.3405 - accuracy: 0.4936
# Epoch 98/500
# 5/5 - 0s - loss: 2.3250 - accuracy: 0.5128
# Epoch 99/500
# 5/5 - 0s - loss: 2.2959 - accuracy: 0.5321
# Epoch 100/500
# 5/5 - 0s - loss: 2.2776 - accuracy: 0.5064
# Epoch 101/500
# 5/5 - 0s - loss: 2.2642 - accuracy: 0.5064
# Epoch 102/500
# 5/5 - 0s - loss: 2.2432 - accuracy: 0.4936
# Epoch 103/500
# 5/5 - 0s - loss: 2.2192 - accuracy: 0.5192
# Epoch 104/500
# 5/5 - 0s - loss: 2.1994 - accuracy: 0.5385
# Epoch 105/500
# 5/5 - 0s - loss: 2.1819 - accuracy: 0.5641
# Epoch 106/500
# 5/5 - 0s - loss: 2.1635 - accuracy: 0.5577
# Epoch 107/500
# 5/5 - 0s - loss: 2.1436 - accuracy: 0.5641
# Epoch 108/500
# 5/5 - 0s - loss: 2.1338 - accuracy: 0.5641
# Epoch 109/500
# 5/5 - 0s - loss: 2.1048 - accuracy: 0.5705
# Epoch 110/500
# 5/5 - 0s - loss: 2.0874 - accuracy: 0.5705
# Epoch 111/500
# 5/5 - 0s - loss: 2.0691 - accuracy: 0.5705
# Epoch 112/500
# 5/5 - 0s - loss: 2.0563 - accuracy: 0.5705
# Epoch 113/500
# 5/5 - 0s - loss: 2.0305 - accuracy: 0.5641
# Epoch 114/500
# 5/5 - 0s - loss: 2.0130 - accuracy: 0.5833
# Epoch 115/500
# 5/5 - 0s - loss: 1.9993 - accuracy: 0.5897
# Epoch 116/500
# 5/5 - 0s - loss: 1.9772 - accuracy: 0.5962
# Epoch 117/500
# 5/5 - 0s - loss: 1.9637 - accuracy: 0.5962
# Epoch 118/500
# 5/5 - 0s - loss: 1.9484 - accuracy: 0.6026
# Epoch 119/500
# 5/5 - 0s - loss: 1.9373 - accuracy: 0.6090
# Epoch 120/500
# 5/5 - 0s - loss: 1.9160 - accuracy: 0.6282
# Epoch 121/500
# 5/5 - 0s - loss: 1.8988 - accuracy: 0.6090
# Epoch 122/500
# 5/5 - 0s - loss: 1.8803 - accuracy: 0.6218
# Epoch 123/500
# 5/5 - 0s - loss: 1.8607 - accuracy: 0.6282
# Epoch 124/500
# 5/5 - 0s - loss: 1.8459 - accuracy: 0.6282
# Epoch 125/500
# 5/5 - 0s - loss: 1.8310 - accuracy: 0.6154
# Epoch 126/500
# 5/5 - 0s - loss: 1.8145 - accuracy: 0.6218
# Epoch 127/500
# 5/5 - 0s - loss: 1.8001 - accuracy: 0.6282
# Epoch 128/500
# 5/5 - 0s - loss: 1.7818 - accuracy: 0.6346
# Epoch 129/500
# 5/5 - 0s - loss: 1.7685 - accuracy: 0.6474
# Epoch 130/500
# 5/5 - 0s - loss: 1.7525 - accuracy: 0.6346
# Epoch 131/500
# 5/5 - 0s - loss: 1.7414 - accuracy: 0.6474
# Epoch 132/500
# 5/5 - 0s - loss: 1.7310 - accuracy: 0.6667
# Epoch 133/500
# 5/5 - 0s - loss: 1.7146 - accuracy: 0.6410
# Epoch 134/500
# 5/5 - 0s - loss: 1.6967 - accuracy: 0.6538
# Epoch 135/500
# 5/5 - 0s - loss: 1.6878 - accuracy: 0.6667
# Epoch 136/500
# 5/5 - 0s - loss: 1.6676 - accuracy: 0.6667
# Epoch 137/500
# 5/5 - 0s - loss: 1.6570 - accuracy: 0.6474
# Epoch 138/500
# 5/5 - 0s - loss: 1.6489 - accuracy: 0.6795
# Epoch 139/500
# 5/5 - 0s - loss: 1.6338 - accuracy: 0.6859
# Epoch 140/500
# 5/5 - 0s - loss: 1.6224 - accuracy: 0.6731
# Epoch 141/500
# 5/5 - 0s - loss: 1.5995 - accuracy: 0.6731
# Epoch 142/500
# 5/5 - 0s - loss: 1.5932 - accuracy: 0.6987
# Epoch 143/500
# 5/5 - 0s - loss: 1.5821 - accuracy: 0.6795
# Epoch 144/500
# 5/5 - 0s - loss: 1.5806 - accuracy: 0.6923
# Epoch 145/500
# 5/5 - 0s - loss: 1.5693 - accuracy: 0.6731
# Epoch 146/500
# 5/5 - 0s - loss: 1.5369 - accuracy: 0.7051
# Epoch 147/500
# 5/5 - 0s - loss: 1.5214 - accuracy: 0.7244
# Epoch 148/500
# 5/5 - 0s - loss: 1.5158 - accuracy: 0.7051
# Epoch 149/500
# 5/5 - 0s - loss: 1.5021 - accuracy: 0.7115
# Epoch 150/500
# 5/5 - 0s - loss: 1.4876 - accuracy: 0.6923
# Epoch 151/500
# 5/5 - 0s - loss: 1.4688 - accuracy: 0.7308
# Epoch 152/500
# 5/5 - 0s - loss: 1.4729 - accuracy: 0.7244
# Epoch 153/500
# 5/5 - 0s - loss: 1.4534 - accuracy: 0.7372
# Epoch 154/500
# 5/5 - 0s - loss: 1.4373 - accuracy: 0.7500
# Epoch 155/500
# 5/5 - 0s - loss: 1.4256 - accuracy: 0.7500
# Epoch 156/500
# 5/5 - 0s - loss: 1.4162 - accuracy: 0.7436
# Epoch 157/500
# 5/5 - 0s - loss: 1.4054 - accuracy: 0.7564
# Epoch 158/500
# 5/5 - 0s - loss: 1.3899 - accuracy: 0.7628
# Epoch 159/500
# 5/5 - 0s - loss: 1.3822 - accuracy: 0.7564
# Epoch 160/500
# 5/5 - 0s - loss: 1.3715 - accuracy: 0.7500
# Epoch 161/500
# 5/5 - 0s - loss: 1.3612 - accuracy: 0.7692
# Epoch 162/500
# 5/5 - 0s - loss: 1.3425 - accuracy: 0.7821
# Epoch 163/500
# 5/5 - 0s - loss: 1.3368 - accuracy: 0.7885
# Epoch 164/500
# 5/5 - 0s - loss: 1.3260 - accuracy: 0.7628
# Epoch 165/500
# 5/5 - 0s - loss: 1.3198 - accuracy: 0.7756
# Epoch 166/500
# 5/5 - 0s - loss: 1.3099 - accuracy: 0.7885
# Epoch 167/500
# 5/5 - 0s - loss: 1.2971 - accuracy: 0.7692
# Epoch 168/500
# 5/5 - 0s - loss: 1.2837 - accuracy: 0.7885
# Epoch 169/500
# 5/5 - 0s - loss: 1.2693 - accuracy: 0.7949
# Epoch 170/500
# 5/5 - 0s - loss: 1.2649 - accuracy: 0.7885
# Epoch 171/500
# 5/5 - 0s - loss: 1.2532 - accuracy: 0.8077
# Epoch 172/500
# 5/5 - 0s - loss: 1.2467 - accuracy: 0.8141
# Epoch 173/500
# 5/5 - 0s - loss: 1.2261 - accuracy: 0.8077
# Epoch 174/500
# 5/5 - 0s - loss: 1.2248 - accuracy: 0.8141
# Epoch 175/500
# 5/5 - 0s - loss: 1.2156 - accuracy: 0.8141
# Epoch 176/500
# 5/5 - 0s - loss: 1.2014 - accuracy: 0.8077
# Epoch 177/500
# 5/5 - 0s - loss: 1.1920 - accuracy: 0.8269
# Epoch 178/500
# 5/5 - 0s - loss: 1.1767 - accuracy: 0.8205
# Epoch 179/500
# 5/5 - 0s - loss: 1.1662 - accuracy: 0.8141
# Epoch 180/500
# 5/5 - 0s - loss: 1.1580 - accuracy: 0.8269
# Epoch 181/500
# 5/5 - 0s - loss: 1.1460 - accuracy: 0.8269
# Epoch 182/500
# 5/5 - 0s - loss: 1.1369 - accuracy: 0.8205
# Epoch 183/500
# 5/5 - 0s - loss: 1.1303 - accuracy: 0.8269
# Epoch 184/500
# 5/5 - 0s - loss: 1.1233 - accuracy: 0.8333
# Epoch 185/500
# 5/5 - 0s - loss: 1.1115 - accuracy: 0.8333
# Epoch 186/500
# 5/5 - 0s - loss: 1.1055 - accuracy: 0.8333
# Epoch 187/500
# 5/5 - 0s - loss: 1.0969 - accuracy: 0.8205
# Epoch 188/500
# 5/5 - 0s - loss: 1.0876 - accuracy: 0.8397
# Epoch 189/500
# 5/5 - 0s - loss: 1.0772 - accuracy: 0.8333
# Epoch 190/500
# 5/5 - 0s - loss: 1.0720 - accuracy: 0.8333
# Epoch 191/500
# 5/5 - 0s - loss: 1.0622 - accuracy: 0.8269
# Epoch 192/500
# 5/5 - 0s - loss: 1.0525 - accuracy: 0.8397
# Epoch 193/500
# 5/5 - 0s - loss: 1.0432 - accuracy: 0.8333
# Epoch 194/500
# 5/5 - 0s - loss: 1.0396 - accuracy: 0.8397
# Epoch 195/500
# 5/5 - 0s - loss: 1.0290 - accuracy: 0.8333
# Epoch 196/500
# 5/5 - 0s - loss: 1.0178 - accuracy: 0.8462
# Epoch 197/500
# 5/5 - 0s - loss: 1.0083 - accuracy: 0.8397
# Epoch 198/500
# 5/5 - 0s - loss: 0.9988 - accuracy: 0.8397
# Epoch 199/500
# 5/5 - 0s - loss: 0.9909 - accuracy: 0.8462
# Epoch 200/500
# 5/5 - 0s - loss: 0.9797 - accuracy: 0.8526
# Epoch 201/500
# 5/5 - 0s - loss: 0.9776 - accuracy: 0.8526
# Epoch 202/500
# 5/5 - 0s - loss: 0.9677 - accuracy: 0.8462
# Epoch 203/500
# 5/5 - 0s - loss: 0.9606 - accuracy: 0.8526
# Epoch 204/500
# 5/5 - 0s - loss: 0.9529 - accuracy: 0.8526
# Epoch 205/500
# 5/5 - 0s - loss: 0.9422 - accuracy: 0.8590
# Epoch 206/500
# 5/5 - 0s - loss: 0.9355 - accuracy: 0.8526
# Epoch 207/500
# 5/5 - 0s - loss: 0.9263 - accuracy: 0.8526
# Epoch 208/500
# 5/5 - 0s - loss: 0.9182 - accuracy: 0.8526
# Epoch 209/500
# 5/5 - 0s - loss: 0.9111 - accuracy: 0.8654
# Epoch 210/500
# 5/5 - 0s - loss: 0.9061 - accuracy: 0.8654
# Epoch 211/500
# 5/5 - 0s - loss: 0.9010 - accuracy: 0.8590
# Epoch 212/500
# 5/5 - 0s - loss: 0.8937 - accuracy: 0.8526
# Epoch 213/500
# 5/5 - 0s - loss: 0.8877 - accuracy: 0.8654
# Epoch 214/500
# 5/5 - 0s - loss: 0.8828 - accuracy: 0.8654
# Epoch 215/500
# 5/5 - 0s - loss: 0.8737 - accuracy: 0.8526
# Epoch 216/500
# 5/5 - 0s - loss: 0.8628 - accuracy: 0.8718
# Epoch 217/500
# 5/5 - 0s - loss: 0.8640 - accuracy: 0.8654
# Epoch 218/500
# 5/5 - 0s - loss: 0.8558 - accuracy: 0.8654
# Epoch 219/500
# 5/5 - 0s - loss: 0.8531 - accuracy: 0.8654
# Epoch 220/500
# 5/5 - 0s - loss: 0.8401 - accuracy: 0.8782
# Epoch 221/500
# 5/5 - 0s - loss: 0.8325 - accuracy: 0.8782
# Epoch 222/500
# 5/5 - 0s - loss: 0.8266 - accuracy: 0.8846
# Epoch 223/500
# 5/5 - 0s - loss: 0.8200 - accuracy: 0.8782
# Epoch 224/500
# 5/5 - 0s - loss: 0.8174 - accuracy: 0.8718
# Epoch 225/500
# 5/5 - 0s - loss: 0.8074 - accuracy: 0.8782
# Epoch 226/500
# 5/5 - 0s - loss: 0.8027 - accuracy: 0.8846
# Epoch 227/500
# 5/5 - 0s - loss: 0.7938 - accuracy: 0.8974
# Epoch 228/500
# 5/5 - 0s - loss: 0.7847 - accuracy: 0.8846
# Epoch 229/500
# 5/5 - 0s - loss: 0.7815 - accuracy: 0.8782
# Epoch 230/500
# 5/5 - 0s - loss: 0.7742 - accuracy: 0.8974
# Epoch 231/500
# 5/5 - 0s - loss: 0.7685 - accuracy: 0.8910
# Epoch 232/500
# 5/5 - 0s - loss: 0.7685 - accuracy: 0.8974
# Epoch 233/500
# 5/5 - 0s - loss: 0.7579 - accuracy: 0.8974
# Epoch 234/500
# 5/5 - 0s - loss: 0.7593 - accuracy: 0.8846
# Epoch 235/500
# 5/5 - 0s - loss: 0.7519 - accuracy: 0.8910
# Epoch 236/500
# 5/5 - 0s - loss: 0.7440 - accuracy: 0.8974
# Epoch 237/500
# 5/5 - 0s - loss: 0.7325 - accuracy: 0.8974
# Epoch 238/500
# 5/5 - 0s - loss: 0.7251 - accuracy: 0.8974
# Epoch 239/500
# 5/5 - 0s - loss: 0.7211 - accuracy: 0.9103
# Epoch 240/500
# 5/5 - 0s - loss: 0.7173 - accuracy: 0.9231
# Epoch 241/500
# 5/5 - 0s - loss: 0.7095 - accuracy: 0.8974
# Epoch 242/500
# 5/5 - 0s - loss: 0.7011 - accuracy: 0.9167
# Epoch 243/500
# 5/5 - 0s - loss: 0.6979 - accuracy: 0.9103
# Epoch 244/500
# 5/5 - 0s - loss: 0.6941 - accuracy: 0.9167
# Epoch 245/500
# 5/5 - 0s - loss: 0.6876 - accuracy: 0.9103
# Epoch 246/500
# 5/5 - 0s - loss: 0.6781 - accuracy: 0.9167
# Epoch 247/500
# 5/5 - 0s - loss: 0.6754 - accuracy: 0.9167
# Epoch 248/500
# 5/5 - 0s - loss: 0.6714 - accuracy: 0.9167
# Epoch 249/500
# 5/5 - 0s - loss: 0.6667 - accuracy: 0.9167
# Epoch 250/500
# 5/5 - 0s - loss: 0.6609 - accuracy: 0.9167
# Epoch 251/500
# 5/5 - 0s - loss: 0.6551 - accuracy: 0.9167
# Epoch 252/500
# 5/5 - 0s - loss: 0.6517 - accuracy: 0.9231
# Epoch 253/500
# 5/5 - 0s - loss: 0.6483 - accuracy: 0.9167
# Epoch 254/500
# 5/5 - 0s - loss: 0.6417 - accuracy: 0.9167
# Epoch 255/500
# 5/5 - 0s - loss: 0.6382 - accuracy: 0.9167
# Epoch 256/500
# 5/5 - 0s - loss: 0.6315 - accuracy: 0.9231
# Epoch 257/500
# 5/5 - 0s - loss: 0.6254 - accuracy: 0.9103
# Epoch 258/500
# 5/5 - 0s - loss: 0.6219 - accuracy: 0.9231
# Epoch 259/500
# 5/5 - 0s - loss: 0.6183 - accuracy: 0.9231
# Epoch 260/500
# 5/5 - 0s - loss: 0.6167 - accuracy: 0.9167
# Epoch 261/500
# 5/5 - 0s - loss: 0.6175 - accuracy: 0.9103
# Epoch 262/500
# 5/5 - 0s - loss: 0.6040 - accuracy: 0.9231
# Epoch 263/500
# 5/5 - 0s - loss: 0.6017 - accuracy: 0.9167
# Epoch 264/500
# 5/5 - 0s - loss: 0.6062 - accuracy: 0.9231
# Epoch 265/500
# 5/5 - 0s - loss: 0.5979 - accuracy: 0.9167
# Epoch 266/500
# 5/5 - 0s - loss: 0.5862 - accuracy: 0.9167
# Epoch 267/500
# 5/5 - 0s - loss: 0.5798 - accuracy: 0.9231
# Epoch 268/500
# 5/5 - 0s - loss: 0.5768 - accuracy: 0.9231
# Epoch 269/500
# 5/5 - 0s - loss: 0.5784 - accuracy: 0.9167
# Epoch 270/500
# 5/5 - 0s - loss: 0.5652 - accuracy: 0.9231
# Epoch 271/500
# 5/5 - 0s - loss: 0.5615 - accuracy: 0.9231
# Epoch 272/500
# 5/5 - 0s - loss: 0.5578 - accuracy: 0.9231
# Epoch 273/500
# 5/5 - 0s - loss: 0.5589 - accuracy: 0.9295
# Epoch 274/500
# 5/5 - 0s - loss: 0.5533 - accuracy: 0.9231
# Epoch 275/500
# 5/5 - 0s - loss: 0.5478 - accuracy: 0.9295
# Epoch 276/500
# 5/5 - 0s - loss: 0.5448 - accuracy: 0.9231
# Epoch 277/500
# 5/5 - 0s - loss: 0.5363 - accuracy: 0.9231
# Epoch 278/500
# 5/5 - 0s - loss: 0.5343 - accuracy: 0.9231
# Epoch 279/500
# 5/5 - 0s - loss: 0.5324 - accuracy: 0.9231
# Epoch 280/500
# 5/5 - 0s - loss: 0.5264 - accuracy: 0.9231
# Epoch 281/500
# 5/5 - 0s - loss: 0.5250 - accuracy: 0.9295
# Epoch 282/500
# 5/5 - 0s - loss: 0.5198 - accuracy: 0.9231
# Epoch 283/500
# 5/5 - 0s - loss: 0.5169 - accuracy: 0.9231
# Epoch 284/500
# 5/5 - 0s - loss: 0.5167 - accuracy: 0.9295
# Epoch 285/500
# 5/5 - 0s - loss: 0.5080 - accuracy: 0.9295
# Epoch 286/500
# 5/5 - 0s - loss: 0.5046 - accuracy: 0.9359
# Epoch 287/500
# 5/5 - 0s - loss: 0.5027 - accuracy: 0.9359
# Epoch 288/500
# 5/5 - 0s - loss: 0.4936 - accuracy: 0.9295
# Epoch 289/500
# 5/5 - 0s - loss: 0.4915 - accuracy: 0.9359
# Epoch 290/500
# 5/5 - 0s - loss: 0.4876 - accuracy: 0.9295
# Epoch 291/500
# 5/5 - 0s - loss: 0.4837 - accuracy: 0.9359
# Epoch 292/500
# 5/5 - 0s - loss: 0.4829 - accuracy: 0.9295
# Epoch 293/500
# 5/5 - 0s - loss: 0.4758 - accuracy: 0.9359
# Epoch 294/500
# 5/5 - 0s - loss: 0.4765 - accuracy: 0.9359
# Epoch 295/500
# 5/5 - 0s - loss: 0.4714 - accuracy: 0.9423
# Epoch 296/500
# 5/5 - 0s - loss: 0.4699 - accuracy: 0.9295
# Epoch 297/500
# 5/5 - 0s - loss: 0.4634 - accuracy: 0.9423
# Epoch 298/500
# 5/5 - 0s - loss: 0.4600 - accuracy: 0.9487
# Epoch 299/500
# 5/5 - 0s - loss: 0.4579 - accuracy: 0.9423
# Epoch 300/500
# 5/5 - 0s - loss: 0.4592 - accuracy: 0.9359
# Epoch 301/500
# 5/5 - 0s - loss: 0.4498 - accuracy: 0.9487
# Epoch 302/500
# 5/5 - 0s - loss: 0.4456 - accuracy: 0.9423
# Epoch 303/500
# 5/5 - 0s - loss: 0.4419 - accuracy: 0.9487
# Epoch 304/500
# 5/5 - 0s - loss: 0.4412 - accuracy: 0.9423
# Epoch 305/500
# 5/5 - 0s - loss: 0.4374 - accuracy: 0.9487
# Epoch 306/500
# 5/5 - 0s - loss: 0.4331 - accuracy: 0.9487
# Epoch 307/500
# 5/5 - 0s - loss: 0.4323 - accuracy: 0.9423
# Epoch 308/500
# 5/5 - 0s - loss: 0.4271 - accuracy: 0.9487
# Epoch 309/500
# 5/5 - 0s - loss: 0.4251 - accuracy: 0.9487
# Epoch 310/500
# 5/5 - 0s - loss: 0.4210 - accuracy: 0.9487
# Epoch 311/500
# 5/5 - 0s - loss: 0.4185 - accuracy: 0.9423
# Epoch 312/500
# 5/5 - 0s - loss: 0.4192 - accuracy: 0.9487
# Epoch 313/500
# 5/5 - 0s - loss: 0.4170 - accuracy: 0.9423
# Epoch 314/500
# 5/5 - 0s - loss: 0.4123 - accuracy: 0.9359
# Epoch 315/500
# 5/5 - 0s - loss: 0.4054 - accuracy: 0.9487
# Epoch 316/500
# 5/5 - 0s - loss: 0.4038 - accuracy: 0.9423
# Epoch 317/500
# 5/5 - 0s - loss: 0.4026 - accuracy: 0.9423
# Epoch 318/500
# 5/5 - 0s - loss: 0.3986 - accuracy: 0.9423
# Epoch 319/500
# 5/5 - 0s - loss: 0.3960 - accuracy: 0.9423
# Epoch 320/500
# 5/5 - 0s - loss: 0.3921 - accuracy: 0.9423
# Epoch 321/500
# 5/5 - 0s - loss: 0.3885 - accuracy: 0.9487
# Epoch 322/500
# 5/5 - 0s - loss: 0.3868 - accuracy: 0.9487
# Epoch 323/500
# 5/5 - 0s - loss: 0.3837 - accuracy: 0.9423
# Epoch 324/500
# 5/5 - 0s - loss: 0.3824 - accuracy: 0.9487
# Epoch 325/500
# 5/5 - 0s - loss: 0.3801 - accuracy: 0.9487
# Epoch 326/500
# 5/5 - 0s - loss: 0.3781 - accuracy: 0.9487
# Epoch 327/500
# 5/5 - 0s - loss: 0.3760 - accuracy: 0.9487
# Epoch 328/500
# 5/5 - 0s - loss: 0.3716 - accuracy: 0.9487
# Epoch 329/500
# 5/5 - 0s - loss: 0.3695 - accuracy: 0.9551
# Epoch 330/500
# 5/5 - 0s - loss: 0.3660 - accuracy: 0.9487
# Epoch 331/500
# 5/5 - 0s - loss: 0.3658 - accuracy: 0.9487
# Epoch 332/500
# 5/5 - 0s - loss: 0.3686 - accuracy: 0.9487
# Epoch 333/500
# 5/5 - 0s - loss: 0.3620 - accuracy: 0.9487
# Epoch 334/500
# 5/5 - 0s - loss: 0.3560 - accuracy: 0.9423
# Epoch 335/500
# 5/5 - 0s - loss: 0.3558 - accuracy: 0.9423
# Epoch 336/500
# 5/5 - 0s - loss: 0.3542 - accuracy: 0.9487
# Epoch 337/500
# 5/5 - 0s - loss: 0.3528 - accuracy: 0.9551
# Epoch 338/500
# 5/5 - 0s - loss: 0.3513 - accuracy: 0.9487
# Epoch 339/500
# 5/5 - 0s - loss: 0.3489 - accuracy: 0.9487
# Epoch 340/500
# 5/5 - 0s - loss: 0.3450 - accuracy: 0.9423
# Epoch 341/500
# 5/5 - 0s - loss: 0.3391 - accuracy: 0.9487
# Epoch 342/500
# 5/5 - 0s - loss: 0.3395 - accuracy: 0.9487
# Epoch 343/500
# 5/5 - 0s - loss: 0.3342 - accuracy: 0.9551
# Epoch 344/500
# 5/5 - 0s - loss: 0.3345 - accuracy: 0.9487
# Epoch 345/500
# 5/5 - 0s - loss: 0.3326 - accuracy: 0.9487
# Epoch 346/500
# 5/5 - 0s - loss: 0.3324 - accuracy: 0.9487
# Epoch 347/500
# 5/5 - 0s - loss: 0.3308 - accuracy: 0.9551
# Epoch 348/500
# 5/5 - 0s - loss: 0.3252 - accuracy: 0.9487
# Epoch 349/500
# 5/5 - 0s - loss: 0.3222 - accuracy: 0.9487
# Epoch 350/500
# 5/5 - 0s - loss: 0.3214 - accuracy: 0.9551
# Epoch 351/500
# 5/5 - 0s - loss: 0.3175 - accuracy: 0.9487
# Epoch 352/500
# 5/5 - 0s - loss: 0.3164 - accuracy: 0.9551
# Epoch 353/500
# 5/5 - 0s - loss: 0.3172 - accuracy: 0.9551
# Epoch 354/500
# 5/5 - 0s - loss: 0.3120 - accuracy: 0.9551
# Epoch 355/500
# 5/5 - 0s - loss: 0.3114 - accuracy: 0.9551
# Epoch 356/500
# 5/5 - 0s - loss: 0.3099 - accuracy: 0.9551
# Epoch 357/500
# 5/5 - 0s - loss: 0.3056 - accuracy: 0.9551
# Epoch 358/500
# 5/5 - 0s - loss: 0.3058 - accuracy: 0.9551
# Epoch 359/500
# 5/5 - 0s - loss: 0.3040 - accuracy: 0.9487
# Epoch 360/500
# 5/5 - 0s - loss: 0.3022 - accuracy: 0.9551
# Epoch 361/500
# 5/5 - 0s - loss: 0.2988 - accuracy: 0.9551
# Epoch 362/500
# 5/5 - 0s - loss: 0.3015 - accuracy: 0.9487
# Epoch 363/500
# 5/5 - 0s - loss: 0.2987 - accuracy: 0.9551
# Epoch 364/500
# 5/5 - 0s - loss: 0.2959 - accuracy: 0.9551
# Epoch 365/500
# 5/5 - 0s - loss: 0.2962 - accuracy: 0.9487
# Epoch 366/500
# 5/5 - 0s - loss: 0.2922 - accuracy: 0.9551
# Epoch 367/500
# 5/5 - 0s - loss: 0.2901 - accuracy: 0.9551
# Epoch 368/500
# 5/5 - 0s - loss: 0.2903 - accuracy: 0.9487
# Epoch 369/500
# 5/5 - 0s - loss: 0.2837 - accuracy: 0.9487
# Epoch 370/500
# 5/5 - 0s - loss: 0.2868 - accuracy: 0.9551
# Epoch 371/500
# 5/5 - 0s - loss: 0.2818 - accuracy: 0.9487
# Epoch 372/500
# 5/5 - 0s - loss: 0.2789 - accuracy: 0.9551
# Epoch 373/500
# 5/5 - 0s - loss: 0.2777 - accuracy: 0.9487
# Epoch 374/500
# 5/5 - 0s - loss: 0.2763 - accuracy: 0.9551
# Epoch 375/500
# 5/5 - 0s - loss: 0.2740 - accuracy: 0.9551
# Epoch 376/500
# 5/5 - 0s - loss: 0.2746 - accuracy: 0.9487
# Epoch 377/500
# 5/5 - 0s - loss: 0.2719 - accuracy: 0.9551
# Epoch 378/500
# 5/5 - 0s - loss: 0.2692 - accuracy: 0.9551
# Epoch 379/500
# 5/5 - 0s - loss: 0.2696 - accuracy: 0.9487
# Epoch 380/500
# 5/5 - 0s - loss: 0.2696 - accuracy: 0.9551
# Epoch 381/500
# 5/5 - 0s - loss: 0.2658 - accuracy: 0.9551
# Epoch 382/500
# 5/5 - 0s - loss: 0.2639 - accuracy: 0.9551
# Epoch 383/500
# 5/5 - 0s - loss: 0.2631 - accuracy: 0.9615
# Epoch 384/500
# 5/5 - 0s - loss: 0.2617 - accuracy: 0.9551
# Epoch 385/500
# 5/5 - 0s - loss: 0.2598 - accuracy: 0.9551
# Epoch 386/500
# 5/5 - 0s - loss: 0.2582 - accuracy: 0.9551
# Epoch 387/500
# 5/5 - 0s - loss: 0.2553 - accuracy: 0.9487
# Epoch 388/500
# 5/5 - 0s - loss: 0.2540 - accuracy: 0.9551
# Epoch 389/500
# 5/5 - 0s - loss: 0.2530 - accuracy: 0.9615
# Epoch 390/500
# 5/5 - 0s - loss: 0.2513 - accuracy: 0.9551
# Epoch 391/500
# 5/5 - 0s - loss: 0.2507 - accuracy: 0.9615
# Epoch 392/500
# 5/5 - 0s - loss: 0.2498 - accuracy: 0.9551
# Epoch 393/500
# 5/5 - 0s - loss: 0.2492 - accuracy: 0.9551
# Epoch 394/500
# 5/5 - 0s - loss: 0.2471 - accuracy: 0.9615
# Epoch 395/500
# 5/5 - 0s - loss: 0.2447 - accuracy: 0.9615
# Epoch 396/500
# 5/5 - 0s - loss: 0.2433 - accuracy: 0.9551
# Epoch 397/500
# 5/5 - 0s - loss: 0.2436 - accuracy: 0.9551
# Epoch 398/500
# 5/5 - 0s - loss: 0.2420 - accuracy: 0.9551
# Epoch 399/500
# 5/5 - 0s - loss: 0.2387 - accuracy: 0.9551
# Epoch 400/500
# 5/5 - 0s - loss: 0.2397 - accuracy: 0.9551
# Epoch 401/500
# 5/5 - 0s - loss: 0.2362 - accuracy: 0.9615
# Epoch 402/500
# 5/5 - 0s - loss: 0.2367 - accuracy: 0.9615
# Epoch 403/500
# 5/5 - 0s - loss: 0.2385 - accuracy: 0.9551
# Epoch 404/500
# 5/5 - 0s - loss: 0.2329 - accuracy: 0.9551
# Epoch 405/500
# 5/5 - 0s - loss: 0.2339 - accuracy: 0.9615
# Epoch 406/500
# 5/5 - 0s - loss: 0.2309 - accuracy: 0.9551
# Epoch 407/500
# 5/5 - 0s - loss: 0.2310 - accuracy: 0.9615
# Epoch 408/500
# 5/5 - 0s - loss: 0.2279 - accuracy: 0.9551
# Epoch 409/500
# 5/5 - 0s - loss: 0.2285 - accuracy: 0.9551
# Epoch 410/500
# 5/5 - 0s - loss: 0.2269 - accuracy: 0.9679
# Epoch 411/500
# 5/5 - 0s - loss: 0.2258 - accuracy: 0.9615
# Epoch 412/500
# 5/5 - 0s - loss: 0.2222 - accuracy: 0.9615
# Epoch 413/500
# 5/5 - 0s - loss: 0.2219 - accuracy: 0.9615
# Epoch 414/500
# 5/5 - 0s - loss: 0.2219 - accuracy: 0.9615
# Epoch 415/500
# 5/5 - 0s - loss: 0.2216 - accuracy: 0.9615
# Epoch 416/500
# 5/5 - 0s - loss: 0.2192 - accuracy: 0.9615
# Epoch 417/500
# 5/5 - 0s - loss: 0.2189 - accuracy: 0.9551
# Epoch 418/500
# 5/5 - 0s - loss: 0.2164 - accuracy: 0.9615
# Epoch 419/500
# 5/5 - 0s - loss: 0.2168 - accuracy: 0.9615
# Epoch 420/500
# 5/5 - 0s - loss: 0.2164 - accuracy: 0.9551
# Epoch 421/500
# 5/5 - 0s - loss: 0.2148 - accuracy: 0.9615
# Epoch 422/500
# 5/5 - 0s - loss: 0.2127 - accuracy: 0.9615
# Epoch 423/500
# 5/5 - 0s - loss: 0.2105 - accuracy: 0.9615
# Epoch 424/500
# 5/5 - 0s - loss: 0.2113 - accuracy: 0.9615
# Epoch 425/500
# 5/5 - 0s - loss: 0.2100 - accuracy: 0.9615
# Epoch 426/500
# 5/5 - 0s - loss: 0.2097 - accuracy: 0.9615
# Epoch 427/500
# 5/5 - 0s - loss: 0.2093 - accuracy: 0.9551
# Epoch 428/500
# 5/5 - 0s - loss: 0.2057 - accuracy: 0.9615
# Epoch 429/500
# 5/5 - 0s - loss: 0.2049 - accuracy: 0.9615
# Epoch 430/500
# 5/5 - 0s - loss: 0.2036 - accuracy: 0.9615
# Epoch 431/500
# 5/5 - 0s - loss: 0.2034 - accuracy: 0.9615
# Epoch 432/500
# 5/5 - 0s - loss: 0.2016 - accuracy: 0.9615
# Epoch 433/500
# 5/5 - 0s - loss: 0.2006 - accuracy: 0.9615
# Epoch 434/500
# 5/5 - 0s - loss: 0.2004 - accuracy: 0.9615
# Epoch 435/500
# 5/5 - 0s - loss: 0.1999 - accuracy: 0.9615
# Epoch 436/500
# 5/5 - 0s - loss: 0.1985 - accuracy: 0.9615
# Epoch 437/500
# 5/5 - 0s - loss: 0.1976 - accuracy: 0.9487
# Epoch 438/500
# 5/5 - 0s - loss: 0.1968 - accuracy: 0.9615
# Epoch 439/500
# 5/5 - 0s - loss: 0.1967 - accuracy: 0.9615
# Epoch 440/500
# 5/5 - 0s - loss: 0.1950 - accuracy: 0.9615
# Epoch 441/500
# 5/5 - 0s - loss: 0.1938 - accuracy: 0.9615
# Epoch 442/500
# 5/5 - 0s - loss: 0.1922 - accuracy: 0.9551
# Epoch 443/500
# 5/5 - 0s - loss: 0.1916 - accuracy: 0.9551
# Epoch 444/500
# 5/5 - 0s - loss: 0.1901 - accuracy: 0.9615
# Epoch 445/500
# 5/5 - 0s - loss: 0.1903 - accuracy: 0.9615
# Epoch 446/500
# 5/5 - 0s - loss: 0.1883 - accuracy: 0.9615
# Epoch 447/500
# 5/5 - 0s - loss: 0.1887 - accuracy: 0.9551
# Epoch 448/500
# 5/5 - 0s - loss: 0.1871 - accuracy: 0.9551
# Epoch 449/500
# 5/5 - 0s - loss: 0.1886 - accuracy: 0.9615
# Epoch 450/500
# 5/5 - 0s - loss: 0.1851 - accuracy: 0.9551
# Epoch 451/500
# 5/5 - 0s - loss: 0.1871 - accuracy: 0.9551
# Epoch 452/500
# 5/5 - 0s - loss: 0.1845 - accuracy: 0.9551
# Epoch 453/500
# 5/5 - 0s - loss: 0.1844 - accuracy: 0.9551
# Epoch 454/500
# 5/5 - 0s - loss: 0.1831 - accuracy: 0.9615
# Epoch 455/500
# 5/5 - 0s - loss: 0.1802 - accuracy: 0.9615
# Epoch 456/500
# 5/5 - 0s - loss: 0.1818 - accuracy: 0.9487
# Epoch 457/500
# 5/5 - 0s - loss: 0.1838 - accuracy: 0.9551
# Epoch 458/500
# 5/5 - 0s - loss: 0.1841 - accuracy: 0.9487
# Epoch 459/500
# 5/5 - 0s - loss: 0.1792 - accuracy: 0.9551
# Epoch 460/500
# 5/5 - 0s - loss: 0.1769 - accuracy: 0.9615
# Epoch 461/500
# 5/5 - 0s - loss: 0.1770 - accuracy: 0.9551
# Epoch 462/500
# 5/5 - 0s - loss: 0.1754 - accuracy: 0.9551
# Epoch 463/500
# 5/5 - 0s - loss: 0.1747 - accuracy: 0.9487
# Epoch 464/500
# 5/5 - 0s - loss: 0.1746 - accuracy: 0.9487
# Epoch 465/500
# 5/5 - 0s - loss: 0.1726 - accuracy: 0.9615
# Epoch 466/500
# 5/5 - 0s - loss: 0.1771 - accuracy: 0.9551
# Epoch 467/500
# 5/5 - 0s - loss: 0.1734 - accuracy: 0.9551
# Epoch 468/500
# 5/5 - 0s - loss: 0.1729 - accuracy: 0.9423
# Epoch 469/500
# 5/5 - 0s - loss: 0.1727 - accuracy: 0.9551
# Epoch 470/500
# 5/5 - 0s - loss: 0.1699 - accuracy: 0.9615
# Epoch 471/500
# 5/5 - 0s - loss: 0.1688 - accuracy: 0.9615
# Epoch 472/500
# 5/5 - 0s - loss: 0.1701 - accuracy: 0.9615
# Epoch 473/500
# 5/5 - 0s - loss: 0.1679 - accuracy: 0.9551
# Epoch 474/500
# 5/5 - 0s - loss: 0.1682 - accuracy: 0.9615
# Epoch 475/500
# 5/5 - 0s - loss: 0.1677 - accuracy: 0.9487
# Epoch 476/500
# 5/5 - 0s - loss: 0.1663 - accuracy: 0.9615
# Epoch 477/500
# 5/5 - 0s - loss: 0.1675 - accuracy: 0.9615
# Epoch 478/500
# 5/5 - 0s - loss: 0.1655 - accuracy: 0.9615
# Epoch 479/500
# 5/5 - 0s - loss: 0.1642 - accuracy: 0.9615
# Epoch 480/500
# 5/5 - 0s - loss: 0.1644 - accuracy: 0.9551
# Epoch 481/500
# 5/5 - 0s - loss: 0.1635 - accuracy: 0.9487
# Epoch 482/500
# 5/5 - 0s - loss: 0.1615 - accuracy: 0.9487
# Epoch 483/500
# 5/5 - 0s - loss: 0.1614 - accuracy: 0.9487
# Epoch 484/500
# 5/5 - 0s - loss: 0.1599 - accuracy: 0.9615
# Epoch 485/500
# 5/5 - 0s - loss: 0.1605 - accuracy: 0.9615
# Epoch 486/500
# 5/5 - 0s - loss: 0.1603 - accuracy: 0.9551
# Epoch 487/500
# 5/5 - 0s - loss: 0.1587 - accuracy: 0.9615
# Epoch 488/500
# 5/5 - 0s - loss: 0.1578 - accuracy: 0.9551
# Epoch 489/500
# 5/5 - 0s - loss: 0.1592 - accuracy: 0.9551
# Epoch 490/500
# 5/5 - 0s - loss: 0.1563 - accuracy: 0.9551
# Epoch 491/500
# 5/5 - 0s - loss: 0.1555 - accuracy: 0.9487
# Epoch 492/500
# 5/5 - 0s - loss: 0.1561 - accuracy: 0.9615
# Epoch 493/500
# 5/5 - 0s - loss: 0.1573 - accuracy: 0.9551
# Epoch 494/500
# 5/5 - 0s - loss: 0.1538 - accuracy: 0.9615
# Epoch 495/500
# 5/5 - 0s - loss: 0.1549 - accuracy: 0.9615
# Epoch 496/500
# 5/5 - 0s - loss: 0.1539 - accuracy: 0.9615
# Epoch 497/500
# 5/5 - 0s - loss: 0.1554 - accuracy: 0.9615
# Epoch 498/500
# 5/5 - 0s - loss: 0.1537 - accuracy: 0.9551
# Epoch 499/500
# 5/5 - 0s - loss: 0.1536 - accuracy: 0.9615
# Epoch 500/500
# 5/5 - 0s - loss: 0.1573 - accuracy: 0.9487

# %% [markdown]
# Running the example achieves a better fit on the source data. The added context has allowed the model to disambiguate some of the examples.
#
# Still two lines of text that start with ‘Jack‘ that may still be a problem for the network.

# %%
# evaluate model
print(generate_seq(model, tokenizer, max_length-1, 'Except', 3))
print(generate_seq(model, tokenizer, max_length-1, 'Now', 7))
# Out:
# Except i wasn't laughing
# Now i only want you gone gone dead

# %% [markdown]
# The first line mnatches the source text. But the second is strange, "Now I only want you gone gone dead"
#
# The network saw" 'Now" within the input seuqence and not at the start of the sequence, so it outputted the word 'Now I only want you gone' which was the last line of the rhyme. However, it got confused on where to stop and merged it with an ambiguious phrase "gone dead." Since there are three lines of "Now I only want you gone," at the end of the input text, the model should have outputted. "Now I only want you gone Now I only."
#
# Better framing may result in better new lines, but for all partial lines of input.
